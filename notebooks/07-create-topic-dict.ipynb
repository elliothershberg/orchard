# %% [markdown]
# # Create Topic Dictionary

# %% [markdown]
# I'm going to create a dictionary of the hierarchical structure of the topics for the bioRxiv data.
#
# I could use the Nomic Python API to do this, but I've since cleaned up the topics, so I'll just do it manually.

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/biorxiv_nomic_normalized.csv')

# %%
df.head()
# Out:
#               doi                                              title  \
# 0  10.1101/000109  Speciation and introgression between Mimulus n...
# 1  10.1101/000075  A Scalable Formulation for Engineering Combina...
# 2  10.1101/000240  Genome-wide targets of selection: female respo...
# 3  10.1101/000208  Population genomics of parallel hybrid zones i...
# 4  10.1101/000398  The Origin of Human-infecting Avian Influenza ...
#
#                                              authors author_corresponding  \
# 0  Yaniv Brandvain;Amanda M Kenney;Lex Fagel;Grah...     Yaniv  Brandvain
# 1   Vanessa Jonsson;Anders Rantzer;Richard M Murray;     Vanessa  Jonsson
# 2        Paolo Innocenti;Ilona Flis;Edward H Morrow;      Edward H Morrow
# 3  Nicola Nadeau;Mayte Ruiz;Patricio Salazar;Bria...        Chri  Jiggins
# 4                    Liangsheng Zhang;Zhenguo Zhang;       Zhenguo  Zhang
#
#                     author_corresponding_institution        date  \
# 0  Department of Evolution and Ecology & Center f...  2013-11-07
# 1                                            Caltech  2013-11-07
# 2                               University of Sussex  2013-11-12
# 3                                          Cambridge  2013-11-12
# 4  Department of Biology, The Pennsylvania State ...  2013-11-14
#
#                 category                                           abstract  \
# 0  Evolutionary Biology   Mimulus guttatus and M. nasutus are an evoluti...
# 1  Evolutionary Biology   It has been shown that optimal controller synt...
# 2  Evolutionary Biology   Despite the common assumption that promiscuity...
# 3  Evolutionary Biology   Hybrid zones can be valuable tools for studyin...
# 4  Evolutionary Biology   In this study, we retraced the origin of the r...
#
#                       published         x         y         topic_depth_1  \
# 0  10.1371/journal.pgen.1004410  0.440659  0.262446  Evolutionary Biology
# 1      10.1109/ACC.2014.6859452 -0.496457 -0.087003     Genomics Analysis
# 2                           NaN  0.359061  0.359294  Evolutionary Biology
# 3         10.1101/gr.169292.113  0.425488  0.269389  Evolutionary Biology
# 4                           NaN  0.562014 -0.578407      Viral Infections
#
#          topic_depth_2          topic_depth_3  id
# 0  Evolutionary Change  Evolutionary Genetics   0
# 1      Systems Biology      Cellular Networks   1
# 2      Animal Behavior   Evolutionary Biology   2
# 3      Animal Behavior       Butterfly Colors   3
# 4    Zoonotic Diseases        Avian Influenza   4

# %%
unique_topic_depth_1 = df['topic_depth_1'].unique().tolist()
unique_topic_depth_1
# Out:
# ['Evolutionary Biology',
#  'Genomics Analysis',
#  'Viral Infections',
#  'Microbial Ecology',
#  'Neural Science',
#  'Cancer Research',
#  'Cell Biology',
#  'Neurological Disorders']

# %% [markdown]
# These aren't super useful, so I think I'll just use the categories for this topic depth.

# %%
unique_topic_depth_2 = df['topic_depth_2'].unique().tolist()
unique_topic_depth_2
# Out:
# ['Evolutionary Change',
#  'Systems Biology',
#  'Animal Behavior',
#  'Zoonotic Diseases',
#  'Evolutionary Dynamics',
#  'Genetic Engineering',
#  'Genetics',
#  'Neural Networks',
#  'Genetic Traits',
#  'Genetic Evolution',
#  'Noncoding RNAs',
#  'Ecosystem Management',
#  'Genomics',
#  'Protein Networks',
#  'Glioblastoma',
#  'Liver Inflammation',
#  'HIV Research',
#  'Plant Stress',
#  'Pharmaceuticals',
#  'Nematode Biology',
#  'Protein Structure',
#  'Aging',
#  'Soil Microbiology',
#  "Alzheimer's Disease",
#  'Parkinsons Disease',
#  'Psychological Disorders',
#  'Embryonic Development',
#  'Mitochondria',
#  'Microbial Pathogens',
#  'Neuroscience',
#  'Muscle Kinematics',
#  'Biomedical Imaging',
#  'Learning Theory',
#  'Memory and Fear',
#  'Virology',
#  'Single Cell',
#  'Malaria',
#  'Influenza Virus',
#  'Gene Expression',
#  'Microscopy',
#  'Microbial Ecology',
#  'Immune Response',
#  'Cell Division',
#  'Honeybees',
#  'Genome Regulation',
#  'Neural Development',
#  'Bacterial Biofilm',
#  'Marine Biology',
#  'Cell Mechanics',
#  'Epigenetic Aging',
#  'Cell Biology',
#  'Brain Processing',
#  'Hearing',
#  'Drosophila Biology',
#  'Disease Control',
#  'Brain Development',
#  'Protein Analysis',
#  'Pulmonary Disease',
#  'Agriculture',
#  'Decision Making',
#  'Diabetes Management',
#  'Gene Editing',
#  'Neuroimaging',
#  'Thermoregulation',
#  'Cancer Treatment',
#  'Ion Channels',
#  'Inflammatory Bowel',
#  'Cell Imaging',
#  'TB Disease',
#  'Zebrafish Biology',
#  'Medical Imaging',
#  'Cancer Immunotherapy',
#  'Cardiovascular',
#  'Microbial Health',
#  'Health Education',
#  'Muscle Disease',
#  'Sleep Rhythms',
#  'Pain Management',
#  'Tissue Engineering',
#  'Eye Vision',
#  'Photosynthesis',
#  'Brain Stimulation',
#  'Antiviral Drugs',
#  'Exosome Biology',
#  'COVID Vaccine',
#  'Staphylococcal Infections',
#  'COVID-19',
#  'Research Paper']

# %%
muscle_kinematics_rows = df[df['topic_depth_2'] == 'Muscle Kinematics']

muscle_kinematics_rows
# Out:
#                               doi  \
# 67                 10.1101/001156
# 403                10.1101/005538
# 1140               10.1101/015040
# 4376               10.1101/056812
# 4874               10.1101/063404
# ...                           ...
# 257992  10.1101/2024.11.21.624713
# 258417  10.1101/2024.11.26.625431
# 258450  10.1101/2024.11.27.625740
# 258635  10.1101/2024.11.25.624926
# 258761  10.1101/2024.11.29.626095
#
#                                                     title  \
# 67      Influence of walking speed on locomotor time p...
# 403     Hip and knee kinematics display complex and ti...
# 1140    Decoding of human hand actions to handle missi...
# 4376    The Human Octopus: controlling supernumerary h...
# 4874    Visual guidance of bimanual coordination relie...
# ...                                                   ...
# 257992  E-bike riding: A metabolic evaluation in the c...
# 258417  Cortical neural activity during responses to m...
# 258450  Changes in interlimb coordination induced by w...
# 258635  Effects of Uni- and Bidirectional Interaction ...
# 258761  Red means heavy: Action intentions reactivate ...
#
#                                                   authors  \
# 67                          Fabrice MEGROT;Carole MEGROT;
# 403        Corey Scholes;Michael McDonald;Anthony Parker;
# 1140                            Jovana Belic;Aldo Faisal;
# 4376    Sander Kulu;Madis Vasser;Raul Vicente Zafra;Ja...
# 4874           Janina Brandes;Farhad Rezvani;Tobias Heed;
# ...                                                   ...
# 257992               Bonardi, A.; Iannetta, D.; Negro, F.
# 258417                       Hooks, K.; Kiani, K.; Fu, Q.
# 258450         Hall, B. L.; Roemmich, R. T.; Banks, C. L.
# 258635  Short, M. R.; Ludvig, D.; Di Tommaso, F.; Vian...
# 258761      Lee, N.; Guo, L. L.; Nestor, A.; Niemeier, M.
#
#        author_corresponding  \
# 67          Fabrice  MEGROT
# 403          Corey  Scholes
# 1140          Jovana  Belic
# 4376              Jaan  Aru
# 4874        Janina  Brandes
# ...                     ...
# 257992      Danilo Iannetta
# 258417            Qiushi Fu
# 258450      Ryan T Roemmich
# 258635      Matthew R Short
# 258761    Matthias Niemeier
#
#                          author_corresponding_institution        date  \
# 67                                       French Red Cross  2013-12-04
# 403                 Sydney Orthopaedic Research Institute  2014-05-26
# 1140                        Royal Institute of Technology  2015-02-09
# 4376    Institute for Computer Science, University of ...  2016-06-03
# 4874    Faculty of Psychology and Human Movement Scien...  2016-07-12
# ...                                                   ...         ...
# 257992                              University of Brescia  2024-11-22
# 258417  Mechanical and Aerospace Engineering, Universi...  2024-11-26
# 258450  Kennedy Krieger Institute/Johns Hopkins Univer...  2024-11-27
# 258635                            Shirley Ryan AbilityLab  2024-11-28
# 258761                              University of Toronto  2024-11-30
#
#               category                                           abstract  \
# 67       Neuroscience   The aim of the present study was to determine ...
# 403        Physiology   The validity of fatigue protocols involving mu...
# 1140     Neuroscience   The only way we can interact with the world is...
# 4376     Neuroscience   We investigated the \"human octopus\" phenomen...
# 4874     Neuroscience   Visual spatial information is paramount in gui...
# ...                ...                                                ...
# 257992      physiology  IntroductionE-bikes are being promoted as a mo...
# 258417    neuroscience  Handedness, as measured by self-reported hand ...
# 258450    neuroscience  During walking, interlimb coordination involve...
# 258635  bioengineering  Haptic human-robot-human interaction allows us...
# 258761    neuroscience  Recent research shows that the intention to ac...
#
#                          published         x         y   topic_depth_1  \
# 67                             NaN  0.046694  0.856476  Neural Science
# 403                            NaN  0.288280  0.735520  Neural Science
# 1140      10.3389/fncom.2015.00027  0.212212  0.699732  Neural Science
# 4376                           NaN  0.195505  0.700397  Neural Science
# 4874    10.1038/s41598-017-16860-x  0.176387  0.710916  Neural Science
# ...                            ...       ...       ...             ...
# 257992                         NaN  0.308692  0.740351  Neural Science
# 258417                         NaN  0.281859  0.812538  Neural Science
# 258450                         NaN  0.279079  0.754857  Neural Science
# 258635                         NaN  0.222113  0.709513  Neural Science
# 258761                         NaN  0.174491  0.701627  Neural Science
#
#             topic_depth_2        topic_depth_3      id
# 67      Muscle Kinematics  Exercise Physiology      67
# 403     Muscle Kinematics  Exercise Physiology     403
# 1140    Muscle Kinematics        Motor Control    1140
# 4376    Muscle Kinematics        Motor Control    4376
# 4874    Muscle Kinematics        Motor Control    4874
# ...                   ...                  ...     ...
# 257992  Muscle Kinematics  Exercise Physiology  257992
# 258417  Muscle Kinematics        Motor Control  258417
# 258450  Muscle Kinematics  Exercise Physiology  258450
# 258635  Muscle Kinematics        Motor Control  258635
# 258761  Muscle Kinematics        Motor Control  258761
#
# [1207 rows x 15 columns]

# %%
honeybees_rows = df[df['topic_depth_2'] == 'Honeybees']
honeybees_rows
# Out:
#                               doi  \
# 122                10.1101/001750
# 139                10.1101/001925
# 175                10.1101/002501
# 265                10.1101/003574
# 630                10.1101/008516
# ...                           ...
# 258324  10.1101/2024.11.26.625348
# 258584  10.1101/2024.11.28.625904
# 258589  10.1101/2024.11.27.625613
# 258604  10.1101/2024.11.27.625616
# 258733  10.1101/2024.11.28.625920
#
#                                                     title  \
# 122     Shifts in stability and control effectiveness ...
# 139     Complex behavioral manipulation drives mismatc...
# 175     Within the fortress: A specialized parasite of...
# 265     3D mapping of disease in ant societies reveals...
# 630     Amino acid and carbohydrate tradeoffs by honey...
# ...                                                   ...
# 258324  Lateralised memory networks explain the use of...
# 258584  Gustatory sensitivity to amino acids in bumble...
# 258589               The swarming behaviors of Vorticella
# 258604  Aggressive conflict impacts path integration i...
# 258733  Convergent mechanisms, divergent strategies: a...
#
#                                                   authors  \
# 122     Dennis Evangelista;Sharlene Cam;Tony Huynh;Aus...
# 139     Fabricio Baccaro;João Araújo;Harry Evans;Jorge...
# 175     Emilia S. Gracia;Charissa de Bekker;Jim Russel...
# 265     Raquel G Loreto;Simon L Elliot;Mayara LR Freit...
# 630     Harmen P. Hendriksma;Karmi L. Oxman;Sharoni Sh...
# ...                                                   ...
# 258324  Filippi, G.; Knight, J.; Philippides, A.; Grah...
# 258584  Rossoni, S.; Parkinson, R. H.; Niven, J. E.; N...
# 258589                            Tabata, T.; Maeyama, Y.
# 258604  Bollig, A.; Freire, M.; Buecking, K.; Kuehnapf...
# 258733  Quinche, L. L.; Garzon-Agudelo, F.; Santana, S...
#
#         author_corresponding  \
# 122      Dennis  Evangelista
# 139            David  Hughes
# 175        Emilia  S. Gracia
# 265          Raquel G Loreto
# 630     Harmen P. Hendriksma
# ...                      ...
# 258324        Giulio Filippi
# 258584    Elizabeth Nicholls
# 258589        Tetsuya Tabata
# 258604         Markus Knaden
# 258733      Laura L. Quinche
#
#                          author_corresponding_institution        date  \
# 122           University of North Carolina at Chapel Hill  2014-01-13
# 139                                            Penn State  2014-01-21
# 175                         Pennsylvania State University  2014-02-07
# 265     Pennsylvania State University & Federal Univer...  2014-03-27
# 630                    The Hebrew University of Jerusalem  2014-08-28
# ...                                                   ...         ...
# 258324                               University of Sussex  2024-11-26
# 258584                               University of Sussex  2024-11-28
# 258589                            The University of Tokyo  2024-11-28
# 258604          Max Planck Institute for Chemical Ecology  2024-11-28
# 258733  Department of Biology, University of Washingto...  2024-11-30
#
#                               category  \
# 122                        Biophysics
# 139                           Ecology
# 175                           Ecology
# 265              Evolutionary Biology
# 630     Animal Behavior and Cognition
# ...                                ...
# 258324                    neuroscience
# 258584                    neuroscience
# 258589   animal behavior and cognition
# 258604   animal behavior and cognition
# 258733                      biophysics
#
#                                                  abstract  \
# 122     The capacity for aerial maneuvering was likely...
# 139     Parasites and hosts are intimately associated ...
# 175     Every level of biological organization from ce...
# 265     Despite the widely held position that the soci...
# 630     Honey bees are important pollinators, requirin...
# ...                                                   ...
# 258324  Many insects use memories of their visual envi...
# 258584  Bees rely on amino acids obtained from nectar ...
# 258589  Two Vorticella species undergo a synchronous t...
# 258604  The desert ant Cataglyphis fortis inhabits the...
# 258733  Nectar-feeding bats exhibit a range of special...
#
#                              published         x         y  \
# 122                  10.7717/peerj.632  0.442054  0.427260
# 139                                NaN  0.843289 -0.015681
# 175                                NaN  0.530758  0.582947
# 265       10.1371/journal.pone.0103516  0.537416  0.577258
# 630     10.1016/j.jinsphys.2014.05.025  0.854429  0.301209
# ...                                ...       ...       ...
# 258324                             NaN  0.498261  0.594319
# 258584                             NaN  0.853556  0.300586
# 258589                             NaN  0.326555 -0.296308
# 258604                             NaN  0.505658  0.592075
# 258733                             NaN  0.504864  0.531322
#
#                topic_depth_1 topic_depth_2      topic_depth_3      id
# 122     Evolutionary Biology     Honeybees         Kinematics     122
# 139     Evolutionary Biology     Honeybees       Ant Colonies     139
# 175     Evolutionary Biology     Honeybees       Ant Colonies     175
# 265     Evolutionary Biology     Honeybees       Ant Colonies     265
# 630     Evolutionary Biology     Honeybees  Honeybee Behavior     630
# ...                      ...           ...                ...     ...
# 258324  Evolutionary Biology     Honeybees       Ant Colonies  258324
# 258584  Evolutionary Biology     Honeybees  Honeybee Behavior  258584
# 258589  Evolutionary Biology     Honeybees         Kinematics  258589
# 258604  Evolutionary Biology     Honeybees       Ant Colonies  258604
# 258733  Evolutionary Biology     Honeybees         Kinematics  258733
#
# [1369 rows x 15 columns]

# %% [markdown]
# Okay, some editing of topic labels for Depth 2:
#
# - Muscle Kinematics -> Motor Control and Movement
# - Honeybees -> Insect Behavior and Ecology
# - Brain Processing -> Cortical Systems and Sensory Processing
# - Cardiovascular -> Cardiovascular Biology
# - Microbial Health -> Microbial Communities
# - Eye Vision -> Eye and Vision Biology
#
# And I'll drop the "Research Paper" topic, because they are all bioRxiv withdrawals.

# %%
unique_topic_depth_3 = df['topic_depth_3'].unique().tolist()
unique_topic_depth_3
# Out:
# ['Evolutionary Genetics',
#  'Cellular Networks',
#  'Evolutionary Biology',
#  'Butterfly Colors',
#  'Avian Influenza',
#  'Genetic Mutations',
#  'Social Networks',
#  'Genetic Evolution',
#  'Sex Determination',
#  'Biological Circuits',
#  'Biotech',
#  'Neural Plasticity',
#  'Genetic Regulation',
#  'Genetics',
#  'MicroRNAs',
#  'Genetic Traits',
#  'Ecological Diversity',
#  'Genetic Analysis',
#  'Gene Expression',
#  'Systems Biology',
#  'Bioinformatics',
#  'Optimal Foraging',
#  'Inflammation Response',
#  'HIV Cure',
#  'Plant Development',
#  'Plant Extracts',
#  'Immune Response',
#  'Neural Behavior',
#  'Brain Connectivity',
#  'Biological Assemblies',
#  'Telomere Maintenance',
#  'Plant Disease',
#  'Viral Infection',
#  "Alzheimer's Disease",
#  'DNA Origami',
#  'Genetic Disorders',
#  'Genetic Variation',
#  'Human Genetics',
#  'Photosynthesis',
#  'Biodiversity Conservation',
#  'Forestry',
#  'Thermal Tolerance',
#  'Cannabis',
#  'Stem Cell Biology',
#  'Mitochondria',
#  'Cancer Microenvironment',
#  'Cancer Biomarkers',
#  'Bacterial Growth',
#  'Genomics',
#  'Statistical Modeling',
#  'Protein Modeling',
#  'Ecological Niche',
#  'Fungal Genetics',
#  'RNA Regulation',
#  'Neuroscience',
#  'Exercise Physiology',
#  'Neuro Imaging',
#  'Brain Function',
#  'Brain Navigation',
#  'Bacterial Genetics',
#  'Epidemiology',
#  'Genetic Selection',
#  'Population Genetics',
#  'Genetic Diversity',
#  'Aging',
#  'Vaccine Science',
#  'Cell Differentiation',
#  'Cell Signaling',
#  'Anatomy',
#  'RNA Structure',
#  'Scientific Software',
#  'Molecular Dynamics',
#  'Brain Networks',
#  'Fluorescence Microscopy',
#  'Brewing',
#  'Botany',
#  'Immune Repertoire',
#  'Ecosystem Dynamics',
#  'Parasite Biology',
#  'Cell Growth',
#  'Kinematics',
#  'Disease Transmission',
#  'Cell Motility',
#  'Cell Division',
#  'Epigenetics',
#  'Glycosylation',
#  'Ant Colonies',
#  'Environmental DNA',
#  'Salmon Genetics',
#  'Genome Assembly',
#  'Cell Transport',
#  'Reproductive Hormones',
#  'Genomic Visualization',
#  'Genetic Risk',
#  'Calcium Signaling',
#  'Data Clustering',
#  'Metabolic Pathways',
#  'Protein Binding',
#  'Single Cell Omics',
#  'Genome Methylation',
#  'Schizophrenia Genetics',
#  'Cell Biology',
#  'Smell System',
#  'Heart Health',
#  'Environmental Science',
#  'Genomic Regulation',
#  'Enzyme Inhibitors',
#  'Developmental Biology',
#  'Psychiatric Disorders',
#  'Neural Circuits',
#  'Metabolic Flux',
#  'Soybean Genetics',
#  'Biosensor Technology',
#  'Behavioral Tracking',
#  'Artificial Intelligence',
#  'Transposons',
#  'Protein Synthesis',
#  'Pulmonary Fibrosis',
#  'Agriculture',
#  'Bacterial Regulation',
#  'Statistical Modelling',
#  'Metacognition',
#  'Bird Migration',
#  'Pancreatic Cells',
#  'Stem Cell',
#  'Auditory Processing',
#  'Chromosome Organization',
#  'Biological Noise',
#  'CRISPR Screening',
#  'Parasite Genomics',
#  'Medical Simulation',
#  'Biology',
#  'Blood Cancer',
#  'Transcription Factors',
#  'Academic Research',
#  'Ion Channel',
#  'Crop Genetics',
#  'Fungi Ecology',
#  'Animal Communication',
#  'Animal Behaviour',
#  'Obesity Research',
#  'Microbial Resistance',
#  'Respiratory Health',
#  'Computer Vision',
#  'Intestinal Cells',
#  'Food Preferences',
#  'Cancer Detection',
#  'Medical Imaging',
#  'Brain Waves',
#  'Protein Interactions',
#  'Noncoding RNAs',
#  'Brain Computer',
#  'Neural Responses',
#  'Gene Regulation',
#  'Cancer',
#  'Antibiotic Resistance',
#  'Learning Theory',
#  'Viral Structure',
#  'Cancer Signaling',
#  'Genetic Recombination',
#  'Biochemical Engineering',
#  'Climate Change',
#  'Wheat Genetics',
#  'Motor Learning',
#  'Infection Response',
#  'Plant Genomes',
#  'Neural Dynamics',
#  'Cancer Genomics',
#  'Genomic Evolution',
#  'Bacterial Symbionts',
#  'Brain Mapping',
#  'Neuronal Plasticity',
#  'Cell Wall',
#  'Cell Death',
#  'Sensory Chemistry',
#  'Parkinsons Disease',
#  'Immune System',
#  'Clostridium difficile',
#  'Microplastic Pollution',
#  'Atherosclerosis',
#  'Genomics Analysis',
#  'Genetic Engineering',
#  'Academic Careers',
#  'Microbial Genomics',
#  'Ecosystem Ecology',
#  'Developmental Dynamics',
#  'Cellular Mechanics',
#  'Immune Cell',
#  'Pharmacology',
#  'Pregnancy',
#  'Honeybee Behavior',
#  'Bee Health',
#  'Biochemistry',
#  'RNA Editing',
#  'Neurotransmitter System',
#  'Perceptual Timing',
#  'Immune Signaling',
#  'Childhood Obesity',
#  'Plant Evolution',
#  'Plant Biology',
#  'Oral Health',
#  'RNA Biology',
#  'Marine Mammals',
#  'Vascular System',
#  'Malaria Control',
#  'Cell Morphology',
#  'Mosquito Control',
#  'Water Quality',
#  'Eye Disease',
#  'Fruit Development',
#  'Protein Analysis',
#  'Reproductive Biology',
#  'Primates',
#  'Infections',
#  'Marine Fisheries',
#  'Symbiotic Relationships',
#  'Muscle Regeneration',
#  'Cell Migration',
#  'Cancer Metastasis',
#  'Species Identification',
#  'Bacterial Infections',
#  'Autism Disorder',
#  'Social Behavior',
#  'Psychedelic Drugs',
#  'Coral Reef',
#  'Livestock Disease',
#  'Healthcare',
#  'Cognitive Control',
#  'Immune Defense',
#  'Diabetes',
#  'Chromatin Dynamics',
#  'Brain Activity',
#  'Epilepsy',
#  'Spinal Cord Injury',
#  'Lipid Metabolism',
#  'Soil Science',
#  'Metabolic Pathway',
#  'Iron Metabolism',
#  'Ocean Ecosystems',
#  'mRNA degradation',
#  'Machine Learning',
#  'Cell Membranes',
#  'Neural Decision',
#  'Bovine TB',
#  'Pregnancy and Birth',
#  'Microbial Communities',
#  'Protein Modification',
#  'Genome Defense',
#  'Sleep Health',
#  'CryoEM Structures',
#  'Biochemical Pathway',
#  'Neurological Pain',
#  'Motor Control',
#  'Spatial Navigation',
#  'Oxidative Stress',
#  'Neurostimulation',
#  'DNA Repair',
#  'Microfluidics',
#  'Neuroimaging Analysis',
#  'Attention',
#  'Microbiology',
#  'Microbial Evolution',
#  'Animal Health',
#  'Immune Cells',
#  'Plant Phenotyping',
#  'Bats and Rabies',
#  'Ocean Microbiology',
#  'Muscular Dystrophy',
#  'Tuberculosis',
#  'Viral Disease',
#  'Neuroimaging',
#  'Animal Behavior',
#  'Water Treatment',
#  'Hibernation Physiology',
#  'Microscopy',
#  'Breast Cancer',
#  'Herbivore Pests',
#  'Single Cell Analysis',
#  "Alzheimer's Diagnosis",
#  'Wildlife Tracking',
#  'Microbial Diversity',
#  'Insect Toxins',
#  'Stress Disorders',
#  'Bacteriophage Therapy',
#  'Cell Trafficking',
#  'Toxicology',
#  'Neurotransmission',
#  'Protein Structure',
#  'Nanoparticle Delivery',
#  'Inflammatory Bowel',
#  'Wildfire Ecology',
#  'Bacterial Division',
#  'Cardiac Physiology',
#  'Aquatic Toxicity',
#  'Zebrafish Genetics',
#  'Herpesvirus',
#  'Protein Enzyme',
#  'Neurology',
#  'Blood Cells',
#  'Hypoxia Response',
#  'Meiotic Process',
#  'Cardiac Disease',
#  'Plant Microbiome',
#  'Bacterial Motility',
#  'Vision',
#  'Stress Response',
#  'Protein Degradation',
#  'Ovarian Development',
#  'Brain Stimulation',
#  'Software Tools',
#  'Cancer Genes',
#  'Nutrition',
#  'Eye Cells',
#  'Viral Replication',
#  'Substance Abuse',
#  'Mitotic Spindle',
#  'RNA Binding',
#  'Circadian Rhythms',
#  'Bacterial Secretion',
#  'Dengue Fever',
#  'Global Health',
#  'Neurodevelopment',
#  'Zika Virus',
#  'Protein Disorder',
#  'Biofilm Formation',
#  'Biological Optics',
#  'Autoimmune Disease',
#  'Magnetic Resonance',
#  'HIV Vaccine',
#  'Memory Processes',
#  'Language Processing',
#  'Antibody Therapeutics',
#  'Cell Adhesion',
#  'Mental Health Disorder',
#  'Music Theory',
#  'Bone Health',
#  'Mass Spectrometry',
#  'Neurodegenerative',
#  'Brain Cancer',
#  'Protein Translation',
#  'Gene Therapy',
#  'Tissue Regeneration',
#  'Antimalarial Treatment',
#  'Disease Surveillance',
#  'Plant Stress',
#  'Viral Assembly',
#  'Neurological Disease',
#  'Pain Receptors',
#  'Tauopathies',
#  'Addiction Genetics',
#  'Pancreatic Cancer',
#  'Vaccine Development',
#  'Bioprinting Materials',
#  'Cellular Degradation',
#  'Neurological Disorders',
#  'Cancer Immunology',
#  'Cilia Structure',
#  'Peptide Sequences',
#  'Emotion Regulation',
#  'DNA Replication',
#  'Brain Chemistry',
#  'Medical',
#  'Sensory Perception',
#  'Epilepsy Genetics',
#  'Vascular Biology',
#  'Anesthesia',
#  'Cancer Therapy',
#  'Kidney Disease',
#  'Social Brain',
#  'Cognitive Decline',
#  'Bacterial Defense',
#  'Neuroanatomy',
#  'Pain Perception',
#  'Malaria Immunity',
#  'Viral Infections',
#  'Cancer Treatment',
#  'Neuroprotective Agents',
#  "Women's Health",
#  'Brain Injury',
#  'Musculoskeletal',
#  'Cyanobacteria',
#  'Multiple Sclerosis',
#  'Viral Diseases',
#  'Speech Processing',
#  'Alcohol Abuse',
#  'Disease Outbreak',
#  'Lung Cancer',
#  'Neonatal Development',
#  'PTSD Response',
#  'Hearing Loss',
#  'Genetic Disease',
#  'Eye Movement',
#  "Huntington's Disease",
#  'Fungal Infections',
#  'Organoid Models',
#  'RNA Modification',
#  'Biomarker Analysis',
#  'Memory Consolidation',
#  'Fibrosis',
#  'Mechanosensitive channels',
#  'Adipose Tissue',
#  'Biomolecular Condensation',
#  'Liver Disease',
#  'Molecular Testing',
#  'Cell Junctions',
#  'Metabolic Changes',
#  'Toxoplasmosis',
#  'Cystic Fibrosis',
#  'Research Paper',
#  'Pulmonary Hypertension',
#  'Fetal Alcohol',
#  'COVID-19',
#  'Vaginal Health',
#  'Viral Entry',
#  'COVID Disease',
#  'Antibody Response',
#  'Virus Variants',
#  'COVID Vaccine']

# %%
len(unique_topic_depth_3)
# Out:
# 418

# %% [markdown]
# Edits for Depth 3:
#
# Based on manual inspection of the abstracts for these topics in the Neon DB console:
#
# - Butterfly Colors -> Color Phenotypes
# - Biotech -> Technology Development
# - Optimal Foraging -> Population-Level Dynamics
# - HIV Cure -> HIV Treatment
# - Brain Navigation -> Hippocampal Research
# - Biology -> Spatial Biology and Environmental Response
# - Academic Research -> Meta-Science
# - Brain Computer -> Brain Computer Interfaces
# - Brain Activity -> Sleep Research
# - Protein Enzyme -> Enzymology
# - Neurodegenerative -> Neurodegeneration
# - Medical -> Bacterial Pathogens
#
# Drop 'Research Paper' because they are all bioRxiv withdrawals.
#
# Identifying similar/redundant topics with ChatGPT o1:
#
# - Animal Behaviour -> Animal Behavior
# - Immune Cell -> Immune Cells
# - Neuro Imaging -> Neuroimaging
# - Metabolic Pathways -> Metabolic Pathway
# - COVID Disease -> COVID-19
# - Genetic Evolution -> Evolutionary Genetics
# - Neuronal Plasticity -> Neural Plasticity
# - Genetic Regulation -> Gene Regulation
# - Genetic Disorders -> Genetic Disease
# - Neurological Disorders -> Neurological Disease
# - Cancer Treatment -> Cancer Therapy

# %%
def replace_value_in_column(df, column, search_value, replace_value):
    """
    Replace occurrences of search_value with replace_value in the specified column of the dataframe.

    Parameters:
    df (pd.DataFrame): The dataframe to modify.
    column (str): The column to search within.
    search_value: The value to search for.
    replace_value: The value to replace the search_value with.

    Returns:
    pd.DataFrame: The modified dataframe with replaced values.
    """
    df[column] = df[column].replace(search_value, replace_value)
    return df

# %%
# Replace specific topic labels in the dataframe
df = replace_value_in_column(df, 'topic_depth_2', 'Muscle Kinematics', 'Motor Control and Movement')
df = replace_value_in_column(df, 'topic_depth_2', 'Honeybees', 'Insect Behavior and Ecology')
df = replace_value_in_column(df, 'topic_depth_2', 'Brain Processing', 'Cortical Systems and Sensory Processing')
df = replace_value_in_column(df, 'topic_depth_2', 'Cardiovascular', 'Cardiovascular Biology')
df = replace_value_in_column(df, 'topic_depth_2', 'Microbial Health', 'Microbial Communities')
df = replace_value_in_column(df, 'topic_depth_2', 'Eye Vision', 'Eye and Vision Biology')

# Drop the "Research Paper" topic
df = df[df['topic_depth_2'] != 'Research Paper']

# %%
# Replace specific topic labels in the dataframe for topic_depth_3
df = replace_value_in_column(df, 'topic_depth_3', 'Butterfly Colors', 'Color Phenotypes')
df = replace_value_in_column(df, 'topic_depth_3', 'Biotech', 'Technology Development')
df = replace_value_in_column(df, 'topic_depth_3', 'Optimal Foraging', 'Population-Level Dynamics')
df = replace_value_in_column(df, 'topic_depth_3', 'HIV Cure', 'HIV Treatment')
df = replace_value_in_column(df, 'topic_depth_3', 'Brain Navigation', 'Hippocampal Research')
df = replace_value_in_column(df, 'topic_depth_3', 'Biology', 'Spatial Biology and Environmental Response')
df = replace_value_in_column(df, 'topic_depth_3', 'Academic Research', 'Meta-Science')
df = replace_value_in_column(df, 'topic_depth_3', 'Brain Computer', 'Brain Computer Interfaces')
df = replace_value_in_column(df, 'topic_depth_3', 'Brain Activity', 'Sleep Research')
df = replace_value_in_column(df, 'topic_depth_3', 'Protein Enzyme', 'Enzymology')
df = replace_value_in_column(df, 'topic_depth_3', 'Neurodegenerative', 'Neurodegeneration')
df = replace_value_in_column(df, 'topic_depth_3', 'Medical', 'Bacterial Pathogens')

# Drop the "Research Paper" topic
df = df[df['topic_depth_3'] != 'Research Paper']

# Identifying similar/redundant topics with ChatGPT o1 for topic_depth_3
df = replace_value_in_column(df, 'topic_depth_3', 'Animal Behaviour', 'Animal Behavior')
df = replace_value_in_column(df, 'topic_depth_3', 'Immune Cell', 'Immune Cells')
df = replace_value_in_column(df, 'topic_depth_3', 'Neuro Imaging', 'Neuroimaging')
df = replace_value_in_column(df, 'topic_depth_3', 'Metabolic Pathways', 'Metabolic Pathway')
df = replace_value_in_column(df, 'topic_depth_3', 'COVID Disease', 'COVID-19')
df = replace_value_in_column(df, 'topic_depth_3', 'Genetic Evolution', 'Evolutionary Genetics')
df = replace_value_in_column(df, 'topic_depth_3', 'Neuronal Plasticity', 'Neural Plasticity')
df = replace_value_in_column(df, 'topic_depth_3', 'Genetic Regulation', 'Gene Regulation')
df = replace_value_in_column(df, 'topic_depth_3', 'Genetic Disorders', 'Genetic Disease')
df = replace_value_in_column(df, 'topic_depth_3', 'Neurological Disorders', 'Neurological Disease')
df = replace_value_in_column(df, 'topic_depth_3', 'Cancer Treatment', 'Cancer Therapy')

# %%
new_unique_topic_depth_3 = df['topic_depth_3'].unique().tolist()

new_unique_topic_depth_3
# Out:
# ['Evolutionary Genetics',
#  'Cellular Networks',
#  'Evolutionary Biology',
#  'Color Phenotypes',
#  'Avian Influenza',
#  'Genetic Mutations',
#  'Social Networks',
#  'Sex Determination',
#  'Biological Circuits',
#  'Technology Development',
#  'Neural Plasticity',
#  'Gene Regulation',
#  'Genetics',
#  'MicroRNAs',
#  'Genetic Traits',
#  'Ecological Diversity',
#  'Genetic Analysis',
#  'Gene Expression',
#  'Systems Biology',
#  'Bioinformatics',
#  'Population-Level Dynamics',
#  'Inflammation Response',
#  'HIV Treatment',
#  'Plant Development',
#  'Plant Extracts',
#  'Immune Response',
#  'Neural Behavior',
#  'Brain Connectivity',
#  'Biological Assemblies',
#  'Telomere Maintenance',
#  'Plant Disease',
#  'Viral Infection',
#  "Alzheimer's Disease",
#  'DNA Origami',
#  'Genetic Disease',
#  'Genetic Variation',
#  'Human Genetics',
#  'Photosynthesis',
#  'Biodiversity Conservation',
#  'Forestry',
#  'Thermal Tolerance',
#  'Cannabis',
#  'Stem Cell Biology',
#  'Mitochondria',
#  'Cancer Microenvironment',
#  'Cancer Biomarkers',
#  'Bacterial Growth',
#  'Genomics',
#  'Statistical Modeling',
#  'Protein Modeling',
#  'Ecological Niche',
#  'Fungal Genetics',
#  'RNA Regulation',
#  'Neuroscience',
#  'Exercise Physiology',
#  'Neuroimaging',
#  'Brain Function',
#  'Hippocampal Research',
#  'Bacterial Genetics',
#  'Epidemiology',
#  'Genetic Selection',
#  'Population Genetics',
#  'Genetic Diversity',
#  'Aging',
#  'Vaccine Science',
#  'Cell Differentiation',
#  'Cell Signaling',
#  'Anatomy',
#  'RNA Structure',
#  'Scientific Software',
#  'Molecular Dynamics',
#  'Brain Networks',
#  'Fluorescence Microscopy',
#  'Brewing',
#  'Botany',
#  'Immune Repertoire',
#  'Ecosystem Dynamics',
#  'Parasite Biology',
#  'Cell Growth',
#  'Kinematics',
#  'Disease Transmission',
#  'Cell Motility',
#  'Cell Division',
#  'Epigenetics',
#  'Glycosylation',
#  'Ant Colonies',
#  'Environmental DNA',
#  'Salmon Genetics',
#  'Genome Assembly',
#  'Cell Transport',
#  'Reproductive Hormones',
#  'Genomic Visualization',
#  'Genetic Risk',
#  'Calcium Signaling',
#  'Data Clustering',
#  'Metabolic Pathway',
#  'Protein Binding',
#  'Single Cell Omics',
#  'Genome Methylation',
#  'Schizophrenia Genetics',
#  'Cell Biology',
#  'Smell System',
#  'Heart Health',
#  'Environmental Science',
#  'Genomic Regulation',
#  'Enzyme Inhibitors',
#  'Developmental Biology',
#  'Psychiatric Disorders',
#  'Neural Circuits',
#  'Metabolic Flux',
#  'Soybean Genetics',
#  'Biosensor Technology',
#  'Behavioral Tracking',
#  'Artificial Intelligence',
#  'Transposons',
#  'Protein Synthesis',
#  'Pulmonary Fibrosis',
#  'Agriculture',
#  'Bacterial Regulation',
#  'Statistical Modelling',
#  'Metacognition',
#  'Bird Migration',
#  'Pancreatic Cells',
#  'Stem Cell',
#  'Auditory Processing',
#  'Chromosome Organization',
#  'Biological Noise',
#  'CRISPR Screening',
#  'Parasite Genomics',
#  'Medical Simulation',
#  'Spatial Biology and Environmental Response',
#  'Blood Cancer',
#  'Transcription Factors',
#  'Meta-Science',
#  'Ion Channel',
#  'Crop Genetics',
#  'Fungi Ecology',
#  'Animal Communication',
#  'Animal Behavior',
#  'Obesity Research',
#  'Microbial Resistance',
#  'Respiratory Health',
#  'Computer Vision',
#  'Intestinal Cells',
#  'Food Preferences',
#  'Cancer Detection',
#  'Medical Imaging',
#  'Brain Waves',
#  'Protein Interactions',
#  'Noncoding RNAs',
#  'Brain Computer Interfaces',
#  'Neural Responses',
#  'Cancer',
#  'Antibiotic Resistance',
#  'Learning Theory',
#  'Viral Structure',
#  'Cancer Signaling',
#  'Genetic Recombination',
#  'Biochemical Engineering',
#  'Climate Change',
#  'Wheat Genetics',
#  'Motor Learning',
#  'Infection Response',
#  'Plant Genomes',
#  'Neural Dynamics',
#  'Cancer Genomics',
#  'Genomic Evolution',
#  'Bacterial Symbionts',
#  'Brain Mapping',
#  'Cell Wall',
#  'Cell Death',
#  'Sensory Chemistry',
#  'Parkinsons Disease',
#  'Immune System',
#  'Clostridium difficile',
#  'Microplastic Pollution',
#  'Atherosclerosis',
#  'Genomics Analysis',
#  'Genetic Engineering',
#  'Academic Careers',
#  'Microbial Genomics',
#  'Ecosystem Ecology',
#  'Developmental Dynamics',
#  'Cellular Mechanics',
#  'Immune Cells',
#  'Pharmacology',
#  'Pregnancy',
#  'Honeybee Behavior',
#  'Bee Health',
#  'Biochemistry',
#  'RNA Editing',
#  'Neurotransmitter System',
#  'Perceptual Timing',
#  'Immune Signaling',
#  'Childhood Obesity',
#  'Plant Evolution',
#  'Plant Biology',
#  'Oral Health',
#  'RNA Biology',
#  'Marine Mammals',
#  'Vascular System',
#  'Malaria Control',
#  'Cell Morphology',
#  'Mosquito Control',
#  'Water Quality',
#  'Eye Disease',
#  'Fruit Development',
#  'Protein Analysis',
#  'Reproductive Biology',
#  'Primates',
#  'Infections',
#  'Marine Fisheries',
#  'Symbiotic Relationships',
#  'Muscle Regeneration',
#  'Cell Migration',
#  'Cancer Metastasis',
#  'Species Identification',
#  'Bacterial Infections',
#  'Autism Disorder',
#  'Social Behavior',
#  'Psychedelic Drugs',
#  'Coral Reef',
#  'Livestock Disease',
#  'Healthcare',
#  'Cognitive Control',
#  'Immune Defense',
#  'Diabetes',
#  'Chromatin Dynamics',
#  'Sleep Research',
#  'Epilepsy',
#  'Spinal Cord Injury',
#  'Lipid Metabolism',
#  'Soil Science',
#  'Iron Metabolism',
#  'Ocean Ecosystems',
#  'mRNA degradation',
#  'Machine Learning',
#  'Cell Membranes',
#  'Neural Decision',
#  'Bovine TB',
#  'Pregnancy and Birth',
#  'Microbial Communities',
#  'Protein Modification',
#  'Genome Defense',
#  'Sleep Health',
#  'CryoEM Structures',
#  'Biochemical Pathway',
#  'Neurological Pain',
#  'Motor Control',
#  'Spatial Navigation',
#  'Oxidative Stress',
#  'Neurostimulation',
#  'DNA Repair',
#  'Microfluidics',
#  'Neuroimaging Analysis',
#  'Attention',
#  'Microbiology',
#  'Microbial Evolution',
#  'Animal Health',
#  'Plant Phenotyping',
#  'Bats and Rabies',
#  'Ocean Microbiology',
#  'Muscular Dystrophy',
#  'Tuberculosis',
#  'Viral Disease',
#  'Water Treatment',
#  'Hibernation Physiology',
#  'Microscopy',
#  'Breast Cancer',
#  'Herbivore Pests',
#  'Single Cell Analysis',
#  "Alzheimer's Diagnosis",
#  'Wildlife Tracking',
#  'Microbial Diversity',
#  'Insect Toxins',
#  'Stress Disorders',
#  'Bacteriophage Therapy',
#  'Cell Trafficking',
#  'Toxicology',
#  'Neurotransmission',
#  'Protein Structure',
#  'Nanoparticle Delivery',
#  'Inflammatory Bowel',
#  'Wildfire Ecology',
#  'Bacterial Division',
#  'Cardiac Physiology',
#  'Aquatic Toxicity',
#  'Zebrafish Genetics',
#  'Herpesvirus',
#  'Enzymology',
#  'Neurology',
#  'Blood Cells',
#  'Hypoxia Response',
#  'Meiotic Process',
#  'Cardiac Disease',
#  'Plant Microbiome',
#  'Bacterial Motility',
#  'Vision',
#  'Stress Response',
#  'Protein Degradation',
#  'Ovarian Development',
#  'Brain Stimulation',
#  'Software Tools',
#  'Cancer Genes',
#  'Nutrition',
#  'Eye Cells',
#  'Viral Replication',
#  'Substance Abuse',
#  'Mitotic Spindle',
#  'RNA Binding',
#  'Circadian Rhythms',
#  'Bacterial Secretion',
#  'Dengue Fever',
#  'Global Health',
#  'Neurodevelopment',
#  'Zika Virus',
#  'Protein Disorder',
#  'Biofilm Formation',
#  'Biological Optics',
#  'Autoimmune Disease',
#  'Magnetic Resonance',
#  'HIV Vaccine',
#  'Memory Processes',
#  'Language Processing',
#  'Antibody Therapeutics',
#  'Cell Adhesion',
#  'Mental Health Disorder',
#  'Music Theory',
#  'Bone Health',
#  'Mass Spectrometry',
#  'Neurodegeneration',
#  'Brain Cancer',
#  'Protein Translation',
#  'Gene Therapy',
#  'Tissue Regeneration',
#  'Antimalarial Treatment',
#  'Disease Surveillance',
#  'Plant Stress',
#  'Viral Assembly',
#  'Neurological Disease',
#  'Pain Receptors',
#  'Tauopathies',
#  'Addiction Genetics',
#  'Pancreatic Cancer',
#  'Vaccine Development',
#  'Bioprinting Materials',
#  'Cellular Degradation',
#  'Cancer Immunology',
#  'Cilia Structure',
#  'Peptide Sequences',
#  'Emotion Regulation',
#  'DNA Replication',
#  'Brain Chemistry',
#  'Bacterial Pathogens',
#  'Sensory Perception',
#  'Epilepsy Genetics',
#  'Vascular Biology',
#  'Anesthesia',
#  'Cancer Therapy',
#  'Kidney Disease',
#  'Social Brain',
#  'Cognitive Decline',
#  'Bacterial Defense',
#  'Neuroanatomy',
#  'Pain Perception',
#  'Malaria Immunity',
#  'Viral Infections',
#  'Neuroprotective Agents',
#  "Women's Health",
#  'Brain Injury',
#  'Musculoskeletal',
#  'Cyanobacteria',
#  'Multiple Sclerosis',
#  'Viral Diseases',
#  'Speech Processing',
#  'Alcohol Abuse',
#  'Disease Outbreak',
#  'Lung Cancer',
#  'Neonatal Development',
#  'PTSD Response',
#  'Hearing Loss',
#  'Eye Movement',
#  "Huntington's Disease",
#  'Fungal Infections',
#  'Organoid Models',
#  'RNA Modification',
#  'Biomarker Analysis',
#  'Memory Consolidation',
#  'Fibrosis',
#  'Mechanosensitive channels',
#  'Adipose Tissue',
#  'Biomolecular Condensation',
#  'Liver Disease',
#  'Molecular Testing',
#  'Cell Junctions',
#  'Metabolic Changes',
#  'Toxoplasmosis',
#  'Cystic Fibrosis',
#  'Pulmonary Hypertension',
#  'Fetal Alcohol',
#  'COVID-19',
#  'Vaginal Health',
#  'Viral Entry',
#  'Antibody Response',
#  'Virus Variants',
#  'COVID Vaccine']

# %%
len(new_unique_topic_depth_3)
# Out:
# 406

# %%
df.to_csv("../data/biorxiv_nomic_edited_topics.csv", index=False)

# %% [markdown]
# ## Save the topic dictionary to JSON

# %%
unique_topic_depth_2 = df['topic_depth_2'].unique().tolist()

# %%
unique_topic_depth_2[0:10]
# Out:
# ['Evolutionary Change',
#  'Systems Biology',
#  'Animal Behavior',
#  'Zoonotic Diseases',
#  'Evolutionary Dynamics',
#  'Genetic Engineering',
#  'Genetics',
#  'Neural Networks',
#  'Genetic Traits',
#  'Genetic Evolution']

# %%
topic_dict = {}

for topic in unique_topic_depth_2:
    subset = df[df['topic_depth_2'] == topic]
    unique_topic_depth_3 = subset['topic_depth_3'].unique().tolist()
    topic_dict[topic] = unique_topic_depth_3

topic_dict
# Out:
# {'Evolutionary Change': ['Evolutionary Genetics',
#   'Thermal Tolerance',
#   'Ecosystem Ecology'],
#  'Systems Biology': ['Cellular Networks',
#   'Statistical Modeling',
#   'Epidemiology',
#   'Data Clustering',
#   'Metabolic Pathway',
#   'Meta-Science'],
#  'Animal Behavior': ['Evolutionary Biology',
#   'Color Phenotypes',
#   'Social Networks',
#   'Population-Level Dynamics',
#   'Ecological Niche',
#   'Behavioral Tracking',
#   'Bird Migration',
#   'Animal Communication',
#   'Animal Behavior',
#   'Primates'],
#  'Zoonotic Diseases': ['Avian Influenza',
#   'Livestock Disease',
#   'Bats and Rabies'],
#  'Evolutionary Dynamics': ['Genetic Mutations',
#   'Bacterial Growth',
#   'Evolutionary Biology',
#   'Aging',
#   'Ecosystem Dynamics',
#   'Disease Transmission',
#   'Microbial Communities'],
#  'Genetic Engineering': ['Evolutionary Genetics',
#   'Biological Circuits',
#   'Technology Development',
#   'Bacterial Genetics',
#   'Transposons',
#   'Antibiotic Resistance',
#   'Microbial Evolution',
#   'Bacteriophage Therapy',
#   'Bacterial Defense'],
#  'Genetics': ['Sex Determination',
#   'Human Genetics',
#   'Genetic Diversity',
#   'Anatomy',
#   'Genetics',
#   'Soybean Genetics',
#   'Genetic Recombination',
#   'Plant Genomes',
#   'Evolutionary Biology',
#   'Genomics',
#   'Plant Biology',
#   'Species Identification',
#   'Animal Health'],
#  'Neural Networks': ['Neural Plasticity',
#   'Brain Connectivity',
#   'Brain Networks',
#   'Artificial Intelligence',
#   'Brain Waves',
#   'Brain Computer Interfaces',
#   'Neural Dynamics',
#   'Neuroscience'],
#  'Genetic Traits': ['Gene Regulation',
#   'Genetic Traits',
#   'Genetic Analysis',
#   'Heart Health'],
#  'Genetic Evolution': ['Genetics',
#   'Genetic Selection',
#   'Population Genetics',
#   'Evolutionary Biology',
#   'Crop Genetics'],
#  'Noncoding RNAs': ['MicroRNAs', 'Noncoding RNAs', 'RNA Biology'],
#  'Ecosystem Management': ['Ecological Diversity',
#   'Biodiversity Conservation',
#   'Forestry',
#   'Botany',
#   'Statistical Modelling',
#   'Wildlife Tracking',
#   'Wildfire Ecology'],
#  'Genomics': ['Gene Expression',
#   'Bioinformatics',
#   'DNA Origami',
#   'Genetic Variation',
#   'Genomics',
#   'Genome Assembly',
#   'Genomic Visualization',
#   'Cancer Detection',
#   'Antibiotic Resistance',
#   'Microbial Genomics'],
#  'Protein Networks': ['Systems Biology',
#   'Protein Modeling',
#   'Scientific Software',
#   'Genomics',
#   'Bioinformatics',
#   'Protein Interactions'],
#  'Glioblastoma': ['Evolutionary Biology',
#   'Cancer Microenvironment',
#   'Cancer Biomarkers',
#   'Genetic Mutations',
#   'Cancer Genomics',
#   'Pharmacology',
#   'Brain Cancer'],
#  'Liver Inflammation': ['Inflammation Response',
#   'Viral Infection',
#   'Immune Response',
#   'Immune Cells',
#   'Autoimmune Disease',
#   'Liver Disease'],
#  'HIV Research': ['HIV Treatment', 'Viral Disease', 'Viral Assembly'],
#  'Plant Stress': ['Plant Development',
#   'Immune Response',
#   'Photosynthesis',
#   'RNA Regulation',
#   'Cell Signaling',
#   'Wheat Genetics',
#   'Metabolic Pathway',
#   'Plant Stress'],
#  'Pharmaceuticals': ['Plant Extracts',
#   'Enzyme Inhibitors',
#   'Machine Learning',
#   'Toxicology',
#   'Cell Signaling',
#   'Peptide Sequences'],
#  'Nematode Biology': ['Neural Behavior',
#   'Cell Biology',
#   'Genetic Variation',
#   'Genome Defense',
#   'Aging'],
#  'Protein Structure': ['Biological Assemblies',
#   'Molecular Dynamics',
#   'Protein Binding',
#   'Evolutionary Genetics',
#   'Biochemistry',
#   'Protein Structure',
#   'Protein Disorder',
#   'Biomolecular Condensation'],
#  'Aging': ['Telomere Maintenance',
#   'Cell Differentiation',
#   'Cell Signaling',
#   'Genomic Regulation',
#   'Transcription Factors',
#   'Cell Death',
#   'Aging',
#   'Hypoxia Response'],
#  'Soil Microbiology': ['Plant Disease',
#   'Fungi Ecology',
#   'Soil Science',
#   'Plant Microbiome'],
#  "Alzheimer's Disease": ["Alzheimer's Disease",
#   "Alzheimer's Diagnosis",
#   'Genetic Risk',
#   'Tauopathies'],
#  'Parkinsons Disease': ['Genetic Disease',
#   'Parkinsons Disease',
#   'Eye Disease',
#   'Spinal Cord Injury',
#   'Neurodevelopment',
#   'Neurodegeneration',
#   'Epilepsy Genetics',
#   'Nutrition',
#   'Neuroprotective Agents',
#   'Multiple Sclerosis',
#   "Huntington's Disease",
#   'Immune Response'],
#  'Psychological Disorders': ['Cannabis',
#   'Reproductive Hormones',
#   'Schizophrenia Genetics',
#   'Food Preferences',
#   'Autism Disorder',
#   'Social Behavior',
#   'Psychedelic Drugs',
#   'Pregnancy and Birth',
#   'Stress Disorders',
#   'Substance Abuse',
#   'Neural Plasticity',
#   'Mental Health Disorder',
#   'Brain Injury',
#   'Alcohol Abuse',
#   'Fetal Alcohol'],
#  'Embryonic Development': ['Stem Cell Biology',
#   'Stem Cell',
#   'Gene Regulation',
#   'Pregnancy',
#   'Cell Morphology',
#   'Blood Cells',
#   'Ovarian Development',
#   'Neuroscience',
#   "Women's Health"],
#  'Mitochondria': ['Mitochondria',
#   'Evolutionary Genetics',
#   'Oxidative Stress',
#   'Parkinsons Disease'],
#  'Microbial Pathogens': ['Fungal Genetics',
#   'Parasite Biology',
#   'Infection Response',
#   'Clostridium difficile',
#   'Infections',
#   'Bacterial Infections',
#   'Insect Toxins',
#   'Disease Outbreak',
#   'Fungal Infections',
#   'Toxoplasmosis'],
#  'Neuroscience': ['Neuroscience',
#   'Neurotransmitter System',
#   'Epilepsy',
#   'Parkinsons Disease',
#   'Neurology',
#   'Sensory Perception',
#   'Neuroanatomy',
#   'Motor Control',
#   'Neurotransmission'],
#  'Motor Control and Movement': ['Exercise Physiology', 'Motor Control'],
#  'Biomedical Imaging': ['Neuroimaging', 'Neurostimulation'],
#  'Learning Theory': ['Brain Function',
#   'Learning Theory',
#   'Motor Learning',
#   'Cognitive Control',
#   'Brain Chemistry',
#   'Social Brain'],
#  'Memory and Fear': ['Hippocampal Research',
#   'Neuroscience',
#   'Memory Processes',
#   'PTSD Response'],
#  'Virology': ['Evolutionary Genetics',
#   'Viral Structure',
#   'Microbial Diversity',
#   'Herpesvirus',
#   'Zika Virus',
#   'Gene Therapy',
#   'Viral Infections',
#   'Immune Response'],
#  'Single Cell': ['Neuroscience',
#   'Single Cell Omics',
#   'Genomic Regulation',
#   'Developmental Dynamics',
#   'Single Cell Analysis',
#   'Spatial Biology and Environmental Response'],
#  'Malaria': ['Plant Extracts',
#   'Parasite Biology',
#   'Malaria Control',
#   'Antimalarial Treatment',
#   'Malaria Immunity'],
#  'Influenza Virus': ['Vaccine Science', 'Viral Replication'],
#  'Gene Expression': ['Genetics',
#   'RNA Structure',
#   'Protein Synthesis',
#   'Biological Noise',
#   'Gene Expression',
#   'Neural Plasticity',
#   'mRNA degradation',
#   'RNA Binding',
#   'Protein Translation'],
#  'Microscopy': ['Fluorescence Microscopy',
#   'Biosensor Technology',
#   'CryoEM Structures',
#   'Microscopy',
#   'Software Tools'],
#  'Microbial Ecology': ['Brewing',
#   'Environmental Science',
#   'Biochemical Engineering',
#   'Symbiotic Relationships',
#   'Ocean Ecosystems',
#   'Microbiology',
#   'Water Treatment',
#   'Antibiotic Resistance'],
#  'Immune Response': ['Immune Repertoire',
#   'HIV Vaccine',
#   'Antibody Therapeutics',
#   'Cancer Immunology'],
#  'Cell Division': ['Cell Growth',
#   'Cell Motility',
#   'Cell Division',
#   'Meiotic Process',
#   'Mitotic Spindle',
#   'Cell Signaling'],
#  'Insect Behavior and Ecology': ['Kinematics',
#   'Ant Colonies',
#   'Honeybee Behavior',
#   'Bee Health'],
#  'Genome Regulation': ['Epigenetics',
#   'Chromosome Organization',
#   'Cell Division',
#   'Chromatin Dynamics',
#   'DNA Repair',
#   'DNA Replication',
#   'RNA Modification'],
#  'Neural Development': ['Evolutionary Biology',
#   'Neuroscience',
#   'Zebrafish Genetics',
#   'Developmental Biology',
#   'Bone Health',
#   'Fibrosis'],
#  'Bacterial Biofilm': ['Glycosylation',
#   'Bacterial Regulation',
#   'Cell Wall',
#   'Iron Metabolism',
#   'Biochemical Pathway',
#   'Bacterial Division',
#   'Bacterial Motility',
#   'Protein Degradation',
#   'Bacterial Secretion',
#   'Biofilm Formation'],
#  'Marine Biology': ['Environmental DNA',
#   'Salmon Genetics',
#   'Climate Change',
#   'Marine Mammals',
#   'Water Quality',
#   'Marine Fisheries',
#   'Coral Reef',
#   'Evolutionary Biology',
#   'Aquatic Toxicity'],
#  'Cell Mechanics': ['Cell Transport',
#   'Cellular Mechanics',
#   'Cell Migration',
#   'Cell Adhesion',
#   'Musculoskeletal',
#   'Mechanosensitive channels'],
#  'Epigenetic Aging': ['Genetic Risk',
#   'Genome Methylation',
#   'Epigenetics',
#   'Plant Evolution',
#   'Aging'],
#  'Cell Biology': ['Calcium Signaling',
#   'Cell Biology',
#   'Cell Signaling',
#   'Immune Signaling',
#   'Lipid Metabolism',
#   'Cell Membranes',
#   'Protein Modification',
#   'Neuroscience',
#   'Cell Trafficking',
#   'Neurotransmission',
#   'Enzymology',
#   'Protein Structure',
#   'Stress Response',
#   "Alzheimer's Disease",
#   'Cellular Degradation',
#   'Cilia Structure',
#   'Cell Junctions'],
#  'Cortical Systems and Sensory Processing': ['Brain Function',
#   'Computer Vision',
#   'Neural Responses',
#   'Brain Mapping',
#   'Perceptual Timing',
#   'Spatial Navigation',
#   'Language Processing',
#   'Emotion Regulation'],
#  'Hearing': ['Smell System',
#   'Auditory Processing',
#   'Music Theory',
#   'Speech Processing',
#   'Hearing Loss'],
#  'Drosophila Biology': ['Developmental Biology',
#   'Neural Circuits',
#   'Gene Regulation',
#   'Reproductive Biology',
#   'Nutrition'],
#  'Disease Control': ['Developmental Biology',
#   'Parasite Genomics',
#   'Bacterial Symbionts',
#   'Sensory Chemistry',
#   'Mosquito Control',
#   'Herbivore Pests',
#   'Disease Surveillance'],
#  'Brain Development': ['Psychiatric Disorders',
#   'Aging',
#   'Neurological Disease',
#   'Cognitive Decline',
#   'Neonatal Development'],
#  'Protein Analysis': ['Metabolic Flux',
#   'Protein Analysis',
#   'Mass Spectrometry'],
#  'Pulmonary Disease': ['Pulmonary Fibrosis',
#   'Respiratory Health',
#   'Cystic Fibrosis'],
#  'Agriculture': ['Agriculture',
#   'Microbial Resistance',
#   'Microplastic Pollution',
#   'Fruit Development',
#   'Plant Phenotyping'],
#  'Decision Making': ['Metacognition', 'Neural Decision'],
#  'Diabetes Management': ['Pancreatic Cells',
#   'Obesity Research',
#   'Diabetes',
#   'Adipose Tissue'],
#  'Gene Editing': ['CRISPR Screening',
#   'Genetic Engineering',
#   'RNA Editing',
#   'Immune Defense'],
#  'Neuroimaging': ['Medical Simulation'],
#  'Thermoregulation': ['Spatial Biology and Environmental Response',
#   'Hibernation Physiology'],
#  'Cancer Treatment': ['Blood Cancer',
#   'Cancer',
#   'Cancer Signaling',
#   'Metabolic Pathway',
#   'Cancer Metastasis',
#   'Breast Cancer',
#   'Cancer Genes',
#   'Pancreatic Cancer',
#   'Cancer Therapy',
#   'Lung Cancer'],
#  'Ion Channels': ['Ion Channel', 'Cell Transport', 'Pain Receptors'],
#  'Inflammatory Bowel': ['Intestinal Cells', 'Inflammatory Bowel'],
#  'Cell Imaging': ['Medical Imaging', 'Immune Cells'],
#  'TB Disease': ['Antibiotic Resistance', 'Bovine TB', 'Tuberculosis'],
#  'Zebrafish Biology': ['Genomic Evolution', 'Animal Behavior'],
#  'Medical Imaging': ['Brain Mapping',
#   'Neuroimaging Analysis',
#   'Neuroimaging',
#   'Magnetic Resonance',
#   'Medical Imaging'],
#  'Cancer Immunotherapy': ['Immune System', 'Immune Cells', 'Cancer Therapy'],
#  'Cardiovascular Biology': ['Atherosclerosis',
#   'Vascular System',
#   'Medical Imaging',
#   'Cardiac Physiology',
#   'Cardiac Disease',
#   'Neurological Disease',
#   'Vascular Biology',
#   'Kidney Disease',
#   'Pulmonary Hypertension'],
#  'Microbial Communities': ['Genomics Analysis',
#   'Oral Health',
#   'Evolutionary Biology',
#   'Metabolic Changes',
#   'Vaginal Health'],
#  'Health Education': ['Academic Careers',
#   'Childhood Obesity',
#   'Healthcare',
#   'Global Health',
#   'Addiction Genetics'],
#  'Muscle Disease': ['Muscle Regeneration', 'Muscular Dystrophy'],
#  'Sleep Rhythms': ['Sleep Research',
#   'Sleep Health',
#   'Circadian Rhythms',
#   'Memory Consolidation'],
#  'Pain Management': ['Neurological Pain',
#   'Pain Perception',
#   'Substance Abuse'],
#  'Tissue Engineering': ['Microfluidics',
#   'Nanoparticle Delivery',
#   'Tissue Regeneration',
#   'Bioprinting Materials',
#   'Organoid Models'],
#  'Eye and Vision Biology': ['Attention',
#   'Vision',
#   'Eye Cells',
#   'Eye Movement'],
#  'Photosynthesis': ['Ocean Microbiology',
#   'Biological Optics',
#   'Photosynthesis',
#   'Cyanobacteria'],
#  'Brain Stimulation': ['Brain Stimulation', 'Anesthesia'],
#  'Antiviral Drugs': ['Dengue Fever', 'Viral Diseases', 'COVID-19'],
#  'Exosome Biology': ['Stem Cell Biology', 'Biomarker Analysis'],
#  'COVID Vaccine': ['Vaccine Development',
#   'Immune Response',
#   'Molecular Testing',
#   'COVID-19',
#   'Nanoparticle Delivery'],
#  'Staphylococcal Infections': ['Bacterial Pathogens'],
#  'COVID-19': ['Genomics',
#   'Viral Replication',
#   'Viral Entry',
#   'COVID-19',
#   'Antibody Response',
#   'Virus Variants',
#   'COVID Vaccine']}

# %%
import json

# Convert topic_dict to the required format
broadTopics = []
specificTopics = []

for idx, (broad_topic, specific_topic_list) in enumerate(topic_dict.items(), start=1):
    broadTopics.append({
        "id": idx,
        "title": broad_topic,
        "specificTopics": specific_topic_list
    })
    specificTopics.extend(specific_topic_list)

broadTopics = sorted(broadTopics, key=lambda x: x['title'])
for idx, topic in enumerate(broadTopics, start=1):
    topic['id'] = idx

# Remove duplicate specific topics and sort
specificTopics = sorted(list(set(specificTopics)))

# Save broadTopics to a JSON file
with open('../data/broadTopics.json', 'w') as f:
    json.dump(broadTopics, f, indent=2)

# Save specificTopics to a JSON file
with open('../data/specificTopics.json', 'w') as f:
    json.dump(specificTopics, f, indent=2)
