# %% [markdown]
# # Create a Full Database

# %% [markdown]
# I've now got all of the bioRxiv abstracts, embeddings, projections, and topics. I'll merge all of these together into one database.

# %%
import pandas as pd
from nomic import AtlasDataset

# %%
df = pd.read_csv("../data/biorxiv_complete_dataset.csv")

# %% [markdown]
# I'll perform all the same filtering as before.

# %%
df = df[df['version'] == 1]
df = df.dropna(subset=['abstract'])
df = df.drop_duplicates(subset=['doi'], keep='first')

# %%
df.shape
# Out:
# (258798, 14)

# %% [markdown]
# And then I'll get the atlas for the projections and topics.

# %%
atlas = AtlasDataset("orchard")
projections = atlas.maps[0].embeddings.projected
# Out:
# 2024-12-13 19:34:21.731 | INFO     | nomic.dataset:__init__:775 - Loading existing dataset `cob/orchard`.
# 2024-12-13 19:34:22.184 | INFO     | nomic.data_operations:_download_projected:538 - Downloading projected embeddings
# 100%|██████████| 21/21 [00:00<00:00, 1560.19it/s]
# 100%|██████████| 21/21 [00:00<00:00, 1354.40it/s]
# 2024-12-13 19:34:22.543 | INFO     | nomic.data_operations:tb:479 - Loading projected embeddings
# 100%|██████████| 21/21 [00:00<00:00, 138.25it/s]

# %%
projections.head()
# Out:
#                          doi          x          y
# 0  10.1101/2023.06.28.546819  24.525175 -10.402438
# 1  10.1101/2020.12.07.415232  14.892089  29.124025
# 2  10.1101/2022.12.05.519101  -2.816088   5.281180
# 3  10.1101/2020.08.11.246504 -23.768440 -23.230116
# 4             10.1101/656314  -7.747561   8.243316

# %%
projections.shape
# Out:
# (258798, 3)

# %%
df.head()
# Out:
#               doi                                              title  \
# 0  10.1101/000109  Speciation and introgression between Mimulus n...
# 1  10.1101/000075  A Scalable Formulation for Engineering Combina...
# 2  10.1101/000240  Genome-wide targets of selection: female respo...
# 3  10.1101/000208  Population genomics of parallel hybrid zones i...
# 4  10.1101/000398  The Origin of Human-infecting Avian Influenza ...
#
#                                              authors author_corresponding  \
# 0  Yaniv Brandvain;Amanda M Kenney;Lex Fagel;Grah...     Yaniv  Brandvain
# 1   Vanessa Jonsson;Anders Rantzer;Richard M Murray;     Vanessa  Jonsson
# 2        Paolo Innocenti;Ilona Flis;Edward H Morrow;      Edward H Morrow
# 3  Nicola Nadeau;Mayte Ruiz;Patricio Salazar;Bria...        Chri  Jiggins
# 4                    Liangsheng Zhang;Zhenguo Zhang;       Zhenguo  Zhang
#
#                     author_corresponding_institution        date  version  \
# 0  Department of Evolution and Ecology & Center f...  2013-11-07        1
# 1                                            Caltech  2013-11-07        1
# 2                               University of Sussex  2013-11-12        1
# 3                                          Cambridge  2013-11-12        1
# 4  Department of Biology, The Pennsylvania State ...  2013-11-14        1
#
#           type      license               category  \
# 0  New Results        cc_by  Evolutionary Biology
# 1  New Results     cc_by_nc  Evolutionary Biology
# 2  New Results        cc_by  Evolutionary Biology
# 3  New Results  cc_by_nc_nd  Evolutionary Biology
# 4  New Results  cc_by_nc_nd  Evolutionary Biology
#
#                                              jatsxml  \
# 0  https://www.biorxiv.org/content/early/2013/11/...
# 1  https://www.biorxiv.org/content/early/2013/11/...
# 2  https://www.biorxiv.org/content/early/2013/11/...
# 3  https://www.biorxiv.org/content/early/2013/11/...
# 4  https://www.biorxiv.org/content/early/2013/11/...
#
#                                             abstract  \
# 0  Mimulus guttatus and M. nasutus are an evoluti...
# 1  It has been shown that optimal controller synt...
# 2  Despite the common assumption that promiscuity...
# 3  Hybrid zones can be valuable tools for studyin...
# 4  In this study, we retraced the origin of the r...
#
#                       published   server
# 0  10.1371/journal.pgen.1004410  biorxiv
# 1      10.1109/ACC.2014.6859452  biorxiv
# 2                           NaN  biorxiv
# 3         10.1101/gr.169292.113  biorxiv
# 4                           NaN  biorxiv

# %%
merged_df = df.merge(projections, on='doi')
merged_df.head()
# Out:
#               doi                                              title  \
# 0  10.1101/000109  Speciation and introgression between Mimulus n...
# 1  10.1101/000075  A Scalable Formulation for Engineering Combina...
# 2  10.1101/000240  Genome-wide targets of selection: female respo...
# 3  10.1101/000208  Population genomics of parallel hybrid zones i...
# 4  10.1101/000398  The Origin of Human-infecting Avian Influenza ...
#
#                                              authors author_corresponding  \
# 0  Yaniv Brandvain;Amanda M Kenney;Lex Fagel;Grah...     Yaniv  Brandvain
# 1   Vanessa Jonsson;Anders Rantzer;Richard M Murray;     Vanessa  Jonsson
# 2        Paolo Innocenti;Ilona Flis;Edward H Morrow;      Edward H Morrow
# 3  Nicola Nadeau;Mayte Ruiz;Patricio Salazar;Bria...        Chri  Jiggins
# 4                    Liangsheng Zhang;Zhenguo Zhang;       Zhenguo  Zhang
#
#                     author_corresponding_institution        date  version  \
# 0  Department of Evolution and Ecology & Center f...  2013-11-07        1
# 1                                            Caltech  2013-11-07        1
# 2                               University of Sussex  2013-11-12        1
# 3                                          Cambridge  2013-11-12        1
# 4  Department of Biology, The Pennsylvania State ...  2013-11-14        1
#
#           type      license               category  \
# 0  New Results        cc_by  Evolutionary Biology
# 1  New Results     cc_by_nc  Evolutionary Biology
# 2  New Results        cc_by  Evolutionary Biology
# 3  New Results  cc_by_nc_nd  Evolutionary Biology
# 4  New Results  cc_by_nc_nd  Evolutionary Biology
#
#                                              jatsxml  \
# 0  https://www.biorxiv.org/content/early/2013/11/...
# 1  https://www.biorxiv.org/content/early/2013/11/...
# 2  https://www.biorxiv.org/content/early/2013/11/...
# 3  https://www.biorxiv.org/content/early/2013/11/...
# 4  https://www.biorxiv.org/content/early/2013/11/...
#
#                                             abstract  \
# 0  Mimulus guttatus and M. nasutus are an evoluti...
# 1  It has been shown that optimal controller synt...
# 2  Despite the common assumption that promiscuity...
# 3  Hybrid zones can be valuable tools for studyin...
# 4  In this study, we retraced the origin of the r...
#
#                       published   server          x          y
# 0  10.1371/journal.pgen.1004410  biorxiv  17.530146  12.635113
# 1      10.1109/ACC.2014.6859452  biorxiv -20.932812  -2.397594
# 2                           NaN  biorxiv  14.181043  16.801380
# 3         10.1101/gr.169292.113  biorxiv  16.907476  12.933809
# 4                           NaN  biorxiv  22.511051 -23.536976

# %%
merged_df[merged_df['doi'] == '10.1101/2023.06.28.546819']
# Out:
#                               doi  \
# 198705  10.1101/2023.06.28.546819
#
#                                                     title  \
# 198705  Discovery of New Broad-Spectrum Anti-Infective...
#
#                                                   authors  \
# 198705  Lin, Y.; Jung, H.; Bulman, C. A.; Ng, J.; Vinc...
#
#        author_corresponding author_corresponding_institution        date  \
# 198705        Gilles Gasser                 Chimie ParisTech  2023-06-30
#
#         version         type license                     category  \
# 198705        1  new results   cc_no  pharmacology and toxicology
#
#                                                   jatsxml  \
# 198705  https://www.biorxiv.org/content/early/2023/06/...
#
#                                                  abstract  \
# 198705  Drug resistance observed with many anti-infect...
#
#                            published   server          x          y
# 198705  10.1021/acs.jmedchem.3c01333  biorxiv  24.525175 -10.402438

# %%
topic_df = atlas.maps[0].topics.df
# Out:
# 2024-12-13 19:34:23.841 | INFO     | nomic.data_operations:_download_topics:189 - Downloading topics
# 100%|██████████| 21/21 [00:00<00:00, 4353.09it/s]
# 100%|██████████| 21/21 [00:00<00:00, 1430.25it/s]
# 2024-12-13 19:34:24.248 | INFO     | nomic.data_operations:_load_topics:151 - Loading topics
# 100%|██████████| 21/21 [00:00<00:00, 50.33it/s]

# %%
topic_df.head()
# Out:
#                          doi               topic_depth_1  \
# 0  10.1101/2023.06.28.546819        Viral Infections (2)
# 1  10.1101/2020.12.07.415232   Evolutionary Biology (10)
# 2  10.1101/2022.12.05.519101           Microbial Ecology
# 3  10.1101/2020.08.11.246504             Cancer Research
# 4             10.1101/656314  Neurological Disorders (2)
#
#             topic_depth_2           topic_depth_3
# 0                 Malaria  Antimalarial Treatment
# 1     Animal Behavior (2)    Animal Communication
# 2      Photosynthesis (4)       Biological Optics
# 3       Genome Regulation              DNA Repair
# 4  Parkinsons Disease (6)             Eye Disease

# %%
merged_df = merged_df.merge(topic_df, on='doi')
merged_df.head()
# Out:
#               doi                                              title  \
# 0  10.1101/000109  Speciation and introgression between Mimulus n...
# 1  10.1101/000075  A Scalable Formulation for Engineering Combina...
# 2  10.1101/000240  Genome-wide targets of selection: female respo...
# 3  10.1101/000208  Population genomics of parallel hybrid zones i...
# 4  10.1101/000398  The Origin of Human-infecting Avian Influenza ...
#
#                                              authors author_corresponding  \
# 0  Yaniv Brandvain;Amanda M Kenney;Lex Fagel;Grah...     Yaniv  Brandvain
# 1   Vanessa Jonsson;Anders Rantzer;Richard M Murray;     Vanessa  Jonsson
# 2        Paolo Innocenti;Ilona Flis;Edward H Morrow;      Edward H Morrow
# 3  Nicola Nadeau;Mayte Ruiz;Patricio Salazar;Bria...        Chri  Jiggins
# 4                    Liangsheng Zhang;Zhenguo Zhang;       Zhenguo  Zhang
#
#                     author_corresponding_institution        date  version  \
# 0  Department of Evolution and Ecology & Center f...  2013-11-07        1
# 1                                            Caltech  2013-11-07        1
# 2                               University of Sussex  2013-11-12        1
# 3                                          Cambridge  2013-11-12        1
# 4  Department of Biology, The Pennsylvania State ...  2013-11-14        1
#
#           type      license               category  \
# 0  New Results        cc_by  Evolutionary Biology
# 1  New Results     cc_by_nc  Evolutionary Biology
# 2  New Results        cc_by  Evolutionary Biology
# 3  New Results  cc_by_nc_nd  Evolutionary Biology
# 4  New Results  cc_by_nc_nd  Evolutionary Biology
#
#                                              jatsxml  \
# 0  https://www.biorxiv.org/content/early/2013/11/...
# 1  https://www.biorxiv.org/content/early/2013/11/...
# 2  https://www.biorxiv.org/content/early/2013/11/...
# 3  https://www.biorxiv.org/content/early/2013/11/...
# 4  https://www.biorxiv.org/content/early/2013/11/...
#
#                                             abstract  \
# 0  Mimulus guttatus and M. nasutus are an evoluti...
# 1  It has been shown that optimal controller synt...
# 2  Despite the common assumption that promiscuity...
# 3  Hybrid zones can be valuable tools for studyin...
# 4  In this study, we retraced the origin of the r...
#
#                       published   server          x          y  \
# 0  10.1371/journal.pgen.1004410  biorxiv  17.530146  12.635113
# 1      10.1109/ACC.2014.6859452  biorxiv -20.932812  -2.397594
# 2                           NaN  biorxiv  14.181043  16.801380
# 3         10.1101/gr.169292.113  biorxiv  16.907476  12.933809
# 4                           NaN  biorxiv  22.511051 -23.536976
#
#                topic_depth_1        topic_depth_2             topic_depth_3
# 0  Evolutionary Biology (10)  Evolutionary Change     Evolutionary Genetics
# 1      Genomics Analysis (2)  Systems Biology (2)         Cellular Networks
# 2  Evolutionary Biology (10)  Animal Behavior (2)  Evolutionary Biology (9)
# 3  Evolutionary Biology (10)  Animal Behavior (2)          Butterfly Colors
# 4       Viral Infections (2)    Zoonotic Diseases           Avian Influenza

# %%
unique_servers = merged_df['server'].unique()
unique_servers
# Out:
# array(['biorxiv'], dtype=object)

# %%
merged_df['type'].unique()
# Out:
# array(['New Results', 'Contradictory Results', 'Confirmatory Results',
#        nan, 'new results', 'confirmatory results',
#        'contradictory results'], dtype=object)

# %%
merged_df = merged_df.drop(columns=['server', 'version', 'jatsxml', 'license', 'type'])

# %%
merged_df.head()
# Out:
#               doi                                              title  \
# 0  10.1101/000109  Speciation and introgression between Mimulus n...
# 1  10.1101/000075  A Scalable Formulation for Engineering Combina...
# 2  10.1101/000240  Genome-wide targets of selection: female respo...
# 3  10.1101/000208  Population genomics of parallel hybrid zones i...
# 4  10.1101/000398  The Origin of Human-infecting Avian Influenza ...
#
#                                              authors author_corresponding  \
# 0  Yaniv Brandvain;Amanda M Kenney;Lex Fagel;Grah...     Yaniv  Brandvain
# 1   Vanessa Jonsson;Anders Rantzer;Richard M Murray;     Vanessa  Jonsson
# 2        Paolo Innocenti;Ilona Flis;Edward H Morrow;      Edward H Morrow
# 3  Nicola Nadeau;Mayte Ruiz;Patricio Salazar;Bria...        Chri  Jiggins
# 4                    Liangsheng Zhang;Zhenguo Zhang;       Zhenguo  Zhang
#
#                     author_corresponding_institution        date  \
# 0  Department of Evolution and Ecology & Center f...  2013-11-07
# 1                                            Caltech  2013-11-07
# 2                               University of Sussex  2013-11-12
# 3                                          Cambridge  2013-11-12
# 4  Department of Biology, The Pennsylvania State ...  2013-11-14
#
#                 category                                           abstract  \
# 0  Evolutionary Biology   Mimulus guttatus and M. nasutus are an evoluti...
# 1  Evolutionary Biology   It has been shown that optimal controller synt...
# 2  Evolutionary Biology   Despite the common assumption that promiscuity...
# 3  Evolutionary Biology   Hybrid zones can be valuable tools for studyin...
# 4  Evolutionary Biology   In this study, we retraced the origin of the r...
#
#                       published          x          y  \
# 0  10.1371/journal.pgen.1004410  17.530146  12.635113
# 1      10.1109/ACC.2014.6859452 -20.932812  -2.397594
# 2                           NaN  14.181043  16.801380
# 3         10.1101/gr.169292.113  16.907476  12.933809
# 4                           NaN  22.511051 -23.536976
#
#                topic_depth_1        topic_depth_2             topic_depth_3
# 0  Evolutionary Biology (10)  Evolutionary Change     Evolutionary Genetics
# 1      Genomics Analysis (2)  Systems Biology (2)         Cellular Networks
# 2  Evolutionary Biology (10)  Animal Behavior (2)  Evolutionary Biology (9)
# 3  Evolutionary Biology (10)  Animal Behavior (2)          Butterfly Colors
# 4       Viral Infections (2)    Zoonotic Diseases           Avian Influenza

# %%
merged_df.to_csv('../data/biorxiv_nomic.csv', index=False)

# %%
unique_topic_depth_1 = merged_df['topic_depth_1'].unique()
unique_topic_depth_1
# Out:
# array(['Evolutionary Biology (10)', 'Genomics Analysis (2)',
#        'Viral Infections (2)', 'Microbial Ecology', 'Neural Science',
#        'Cancer Research', 'Cell Biology (4)',
#        'Neurological Disorders (2)'], dtype=object)

# %%
unique_topic_depth_2 = merged_df['topic_depth_2'].unique()
unique_topic_depth_2
# Out:
# array(['Evolutionary Change', 'Systems Biology (2)',
#        'Animal Behavior (2)', 'Zoonotic Diseases',
#        'Evolutionary Dynamics', 'Genetic Engineering (2)', 'Genetics (5)',
#        'Neural Networks', 'Genetic Traits (2)', 'Genetic Evolution (5)',
#        'Noncoding RNAs', 'Ecosystem Management', 'Genomics (6)',
#        'Protein Networks', 'Glioblastoma', 'Liver Inflammation',
#        'HIV Research', 'Plant Stress (2)', 'Pharmaceuticals',
#        'Nematode Biology', 'Protein Structure (3)', 'Aging',
#        'Soil Microbiology', "Alzheimer's Disease (4)",
#        'Parkinsons Disease (6)', 'Genetics (4)',
#        'Psychological Disorders', 'Embryonic Development',
#        'Mitochondria (2)', 'Microbial Pathogens', 'Neuroscience (9)',
#        'Muscle Kinematics', 'Biomedical Imaging', 'Learning Theory (2)',
#        'Memory and Fear', 'Virology', 'Single Cell', 'Malaria',
#        'Influenza Virus', 'Gene Expression (3)', 'Microscopy (2)',
#        'Microbial Ecology (2)', 'Immune Response (7)',
#        'Cell Division (4)', 'Honeybees', 'Genome Regulation',
#        'Neural Development', 'Bacterial Biofilm', 'Marine Biology',
#        'Cell Mechanics', 'Epigenetic Aging', 'Cell Biology (5)',
#        'Brain Processing', 'Hearing', 'Drosophila Biology',
#        'Disease Control', 'Brain Development', 'Protein Analysis (2)',
#        'Pulmonary Disease', 'Agriculture (2)', 'Decision Making',
#        'Diabetes Management', 'Gene Editing', 'Neuroimaging (2)',
#        'Thermoregulation', 'Cancer Treatment (3)', 'Ion Channels',
#        'Inflammatory Bowel (2)', 'Cell Imaging', 'TB Disease',
#        'Zebrafish Biology', 'Medical Imaging (4)', 'Cancer Immunotherapy',
#        'Cardiovascular (2)', 'Microbial Health', 'Health Education',
#        'Cardiovascular', 'Muscle Disease', 'Sleep Rhythms',
#        'Pain Management', 'Tissue Engineering', 'Eye Vision',
#        'Photosynthesis (4)', 'Brain Stimulation (2)', 'Antiviral Drugs',
#        'Exosome Biology', 'COVID Vaccine (2)',
#        'Staphylococcal Infections', 'COVID-19 (3)', 'Research Paper (2)'],
#       dtype=object)

# %%
len(unique_topic_depth_2)
# Out:
# 90

# %%
unique_topic_depth_3 = merged_df['topic_depth_3'].unique()
unique_topic_depth_3
# Out:
# array(['Evolutionary Genetics', 'Cellular Networks',
#        'Evolutionary Biology (9)', 'Butterfly Colors', 'Avian Influenza',
#        'Genetic Mutations (2)', 'Social Networks',
#        'Genetic Evolution (2)', 'Sex Determination',
#        'Biological Circuits', 'Biotech', 'Neural Plasticity',
#        'Genetic Regulation (2)', 'Genetics (2)', 'MicroRNAs',
#        'Genetic Traits', 'Ecological Diversity', 'Genetic Analysis (2)',
#        'Gene Expression (2)', 'Systems Biology', 'Bioinformatics (3)',
#        'Evolutionary Biology (2)', 'Optimal Foraging',
#        'Inflammation Response', 'HIV Cure', 'Plant Development',
#        'Plant Extracts (2)', 'Immune Response (3)', 'Neural Behavior',
#        'Brain Connectivity', 'Biological Assemblies',
#        'Telomere Maintenance', 'Plant Disease', 'Viral Infection',
#        "Alzheimer's Disease (3)", 'DNA Origami', 'Genetic Disorders',
#        'Genetic Variation (3)', 'Human Genetics', 'Genetic Analysis',
#        'Photosynthesis (3)', 'Biodiversity Conservation', 'Forestry',
#        'Thermal Tolerance', 'Cannabis', 'Stem Cell Biology',
#        'Mitochondria', 'Cancer Microenvironment', 'Cancer Biomarkers',
#        'Bacterial Growth', 'Genomics (3)', 'Statistical Modeling',
#        'Evolutionary Biology (7)', 'Protein Modeling', 'Ecological Niche',
#        'Fungal Genetics', 'RNA Regulation', 'Neuroscience (3)',
#        'Exercise Physiology', 'Neuro Imaging', 'Brain Function',
#        'Brain Navigation', 'Genetic Evolution', 'Bacterial Genetics',
#        'Epidemiology', 'Genetic Selection', 'Population Genetics',
#        'Genetic Diversity', 'Aging (6)', 'Neuroscience (8)',
#        'Evolutionary Biology (4)', 'Plant Extracts', 'Vaccine Science',
#        'Cell Differentiation', 'Genetic Mutations', 'Genetics',
#        'Cell Signaling (2)', 'Anatomy', 'RNA Structure',
#        'Scientific Software', 'Molecular Dynamics', 'Brain Networks',
#        'Fluorescence Microscopy', 'Brewing', 'Botany',
#        'Genetic Evolution (4)', 'Immune Repertoire', 'Genomics (2)',
#        'Ecosystem Dynamics', 'Parasite Biology (2)', 'Cell Growth',
#        'Kinematics', 'Disease Transmission', 'Cell Motility',
#        'Cell Division (2)', 'Epigenetics (2)', 'Evolutionary Biology (3)',
#        'Genetic Variation (2)', 'Bioinformatics (2)', 'Glycosylation',
#        'Ant Colonies', 'Environmental DNA', 'Salmon Genetics',
#        'Genome Assembly', 'Cell Transport (2)', 'Reproductive Hormones',
#        'Genetic Disorders (2)', 'Genomic Visualization', 'Genetic Risk',
#        'Calcium Signaling', 'Parasite Biology', 'Data Clustering',
#        'Metabolic Pathways (2)', 'Protein Binding', 'Single Cell Omics',
#        'Brain Function (2)', 'Genome Methylation',
#        'Schizophrenia Genetics', 'Cell Biology',
#        'Evolutionary Biology (8)', 'Smell System', 'Genetics (3)',
#        'Heart Health', 'Environmental Science', 'Genomic Regulation',
#        'Enzyme Inhibitors', 'Developmental Biology',
#        'Developmental Biology (3)', 'Psychiatric Disorders',
#        'Neural Circuits', 'Metabolic Flux', 'Soybean Genetics',
#        'Biosensor Technology', 'Evolutionary Genetics (2)',
#        'Behavioral Tracking', 'Artificial Intelligence',
#        'Cell Biology (3)', 'Transposons', 'Protein Synthesis',
#        'Epigenetics (4)', 'Pulmonary Fibrosis', 'Cell Signaling',
#        'Agriculture', 'Bacterial Regulation', 'Statistical Modelling',
#        'Metacognition', 'Bird Migration', 'Pancreatic Cells', 'Stem Cell',
#        'Auditory Processing', 'Chromosome Organization',
#        'Biological Noise', 'CRISPR Screening', 'Parasite Genomics',
#        'Medical Simulation', 'Biology', 'Blood Cancer',
#        'Transcription Factors', 'Academic Research',
#        'Genomic Regulation (2)', 'Ion Channel', 'Crop Genetics',
#        'Fungi Ecology', 'Genetic Evolution (3)', 'Animal Communication',
#        'Animal Behaviour', 'Obesity Research', 'Microbial Resistance',
#        'Respiratory Health', 'Computer Vision', 'Intestinal Cells',
#        'Food Preferences', 'Cancer Detection', 'Medical Imaging (3)',
#        'Brain Waves', 'Protein Interactions', 'Noncoding RNAs (2)',
#        'Brain Computer', 'Neural Responses', 'Gene Regulation',
#        'Gene Expression', 'Cell Division (3)', 'Cancer',
#        'Genetic Regulation', 'Antibiotic Resistance', 'Learning Theory',
#        'Viral Structure', 'Cancer Signaling', 'Genetic Recombination',
#        'Biochemical Engineering', 'Climate Change', 'Wheat Genetics',
#        'Motor Learning', 'Infection Response', 'Plant Genomes',
#        'Neural Dynamics', 'Evolutionary Biology (5)', 'Genomics (4)',
#        'Genomics (5)', 'Cancer Genomics', 'Genomic Evolution',
#        'Bacterial Symbionts', 'Cell Signaling (4)', 'Brain Mapping (2)',
#        'Neuronal Plasticity', 'Cell Wall', 'Cell Death',
#        'Antibiotic Resistance (5)', 'Brain Mapping', 'Sensory Chemistry',
#        'Parkinsons Disease (3)', 'Immune System', 'Clostridium difficile',
#        'Microplastic Pollution', 'Atherosclerosis', 'Genomics Analysis',
#        'Genetic Engineering', 'Academic Careers', 'Microbial Genomics',
#        'Antibiotic Resistance (2)', 'Ecosystem Ecology',
#        'Developmental Dynamics', 'Cellular Mechanics (2)', 'Immune Cell',
#        'Bioinformatics', 'Pharmacology', 'Pregnancy', 'Honeybee Behavior',
#        'Bee Health', 'Biochemistry', 'Metabolic Pathways', 'RNA Editing',
#        'Neurotransmitter System', 'Perceptual Timing', 'Immune Signaling',
#        'Childhood Obesity', 'Plant Evolution', 'Plant Biology',
#        'Oral Health', 'RNA Biology', 'Marine Mammals', 'Vascular System',
#        'Malaria Control', 'Cell Morphology', 'Mosquito Control',
#        'Water Quality', 'Eye Disease', 'Fruit Development',
#        'Protein Analysis', 'Reproductive Biology', 'Primates',
#        'Infections', 'Marine Fisheries', 'Symbiotic Relationships',
#        'Neuroscience (4)', 'Muscle Regeneration', 'Cell Migration',
#        'Cancer Metastasis', 'Species Identification',
#        'Bacterial Infections', 'Genetic Variation', 'Autism Disorder',
#        'Cell Division', 'Social Behavior', 'Psychedelic Drugs',
#        'Coral Reef', 'Livestock Disease', 'Healthcare',
#        'Cognitive Control', 'Immune Defense', 'Diabetes',
#        'Chromatin Dynamics', 'Brain Activity', 'Epilepsy',
#        'Spinal Cord Injury', 'Lipid Metabolism', 'Soil Science',
#        'Metabolic Pathway', 'Iron Metabolism', 'Ocean Ecosystems',
#        'mRNA degradation', 'Machine Learning', 'Cell Membranes',
#        'Cell Transport', 'Neural Decision', 'Bovine TB',
#        'Pregnancy and Birth', 'Microbial Communities',
#        'Protein Modification', 'Genome Defense', 'Parkinsons Disease',
#        'Sleep Health', 'CryoEM Structures', 'Neuroscience (2)',
#        'Biochemical Pathway', 'Immune Response (5)', 'Neurological Pain',
#        'Motor Control', 'Spatial Navigation', 'Oxidative Stress',
#        'Neurostimulation', 'DNA Repair', 'Microfluidics',
#        'Neuroimaging Analysis', 'Attention', 'Neuroscience (7)',
#        'Microbiology', 'Microbial Evolution', 'Neuroscience (6)',
#        'Cell Biology (2)', 'Cellular Mechanics', 'Animal Health',
#        'Evolutionary Biology', 'Medical Imaging', 'Immune Cells (2)',
#        'Plant Phenotyping', 'Bats and Rabies', 'Ocean Microbiology',
#        'Muscular Dystrophy', 'Tuberculosis (2)', 'Viral Disease',
#        'Neuroimaging', 'Aging (3)', 'Animal Behavior', 'Water Treatment',
#        'Hibernation Physiology', 'Microscopy', 'Breast Cancer',
#        'Herbivore Pests', 'Evolutionary Biology (6)',
#        'Single Cell Analysis', 'Neuroscience', "Alzheimer's Diagnosis",
#        'Wildlife Tracking', 'Microbial Diversity', 'Tuberculosis',
#        'Insect Toxins', 'Stress Disorders', 'Bacteriophage Therapy',
#        'Cell Trafficking', 'Toxicology', 'Aging (5)',
#        'Neurotransmission (2)', 'Aging (2)', 'Biology (2)',
#        'Protein Structure', 'Nanoparticle Delivery (2)',
#        'Inflammatory Bowel', 'Wildfire Ecology', 'Bacterial Division',
#        'Cardiac Physiology', 'Aquatic Toxicity', 'Zebrafish Genetics',
#        'Herpesvirus', 'Protein Enzyme', 'Parkinsons Disease (2)',
#        'Neurology', 'Blood Cells', 'Hypoxia Response', 'Meiotic Process',
#        'Cardiac Disease', 'Plant Microbiome', 'Aging (4)',
#        'Bacterial Motility', 'Vision', 'Protein Structure (2)',
#        'Stress Response', 'Protein Degradation', 'Ovarian Development',
#        'Brain Stimulation', 'Software Tools', 'Cancer Genes', 'Nutrition',
#        'Eye Cells', 'Viral Replication (2)', 'Genetic Risk (2)',
#        'Substance Abuse', 'Mitotic Spindle', 'RNA Binding',
#        'Circadian Rhythms', 'Immune Cells', 'Antibiotic Resistance (3)',
#        'Bacterial Secretion', 'Dengue Fever', 'Global Health',
#        'Neurodevelopment', 'Cell Signaling (3)', 'Zika Virus',
#        'Protein Disorder', 'Biofilm Formation', 'Biological Optics',
#        'Developmental Biology (2)', 'Autoimmune Disease',
#        'Magnetic Resonance', 'Neural Plasticity (2)',
#        "Alzheimer's Disease", 'HIV Vaccine', 'Memory Processes',
#        'Language Processing', 'Epigenetics (3)', 'Antibody Therapeutics',
#        'Cell Adhesion', 'Mental Health Disorder', 'Music Theory',
#        'Bone Health', 'Mass Spectrometry', 'Neurodegenerative',
#        'Immune Response (4)', 'Brain Cancer', 'Protein Translation',
#        'Gene Therapy', 'Tissue Regeneration', 'Medical Imaging (2)',
#        'Antimalarial Treatment', 'Stem Cell Biology (2)',
#        'Disease Surveillance', 'Plant Stress', 'Viral Assembly',
#        'Neurological Disease', 'Pain Receptors', 'Tauopathies',
#        'Addiction Genetics', 'Pancreatic Cancer',
#        'Vaccine Development (2)', 'Bioprinting Materials',
#        'Cellular Degradation', 'Neurological Disorders',
#        'Cancer Immunology', 'Cilia Structure', 'Peptide Sequences',
#        'Emotion Regulation', 'DNA Replication', 'Brain Chemistry',
#        'Medical', 'Sensory Perception', 'Epilepsy Genetics',
#        'Neuroscience (5)', 'Vascular Biology', 'Anesthesia',
#        'Photosynthesis', 'Cancer Therapy', 'Kidney Disease',
#        'Social Brain', 'Cognitive Decline', 'Bacterial Defense',
#        'Neuroanatomy', 'Pain Perception', 'Nutrition (2)',
#        'Malaria Immunity', 'Motor Control (2)', 'Viral Infections',
#        'Cancer Treatment (2)', 'Neuroprotective Agents', "Women's Health",
#        'Brain Injury', 'Musculoskeletal', 'Immune Response',
#        'Cyanobacteria', 'Cancer Treatment', 'Multiple Sclerosis',
#        'Neurotransmission', 'Immune Response (2)', 'Viral Diseases',
#        'Epigenetics', 'Speech Processing', 'Alcohol Abuse',
#        'Disease Outbreak', 'Lung Cancer', 'Substance Abuse (2)',
#        'Neonatal Development', 'PTSD Response', 'Hearing Loss',
#        'Photosynthesis (2)', 'Genetic Disease', 'Eye Movement',
#        "Huntington's Disease", 'Fungal Infections', 'Organoid Models',
#        'RNA Modification', 'Cell Signaling (5)', 'Biomarker Analysis',
#        'Memory Consolidation', 'Immune Response (6)', 'Fibrosis',
#        'Mechanosensitive channels', 'Adipose Tissue',
#        'Biomolecular Condensation', 'Antibiotic Resistance (4)',
#        'Liver Disease', 'Molecular Testing', 'Cell Junctions',
#        'Metabolic Changes', "Alzheimer's Disease (2)", 'Genomics',
#        'Toxoplasmosis', 'Parkinsons Disease (4)', 'Cystic Fibrosis',
#        'Parkinsons Disease (5)', 'Research Paper',
#        'Pulmonary Hypertension', 'Fetal Alcohol', 'Viral Replication',
#        'COVID-19', 'Vaginal Health', 'COVID-19 (2)', 'Viral Entry',
#        'COVID Disease', 'Vaccine Development', 'Nanoparticle Delivery',
#        'Antibody Response', 'Virus Variants', 'COVID Vaccine'],
#       dtype=object)

# %%
len(unique_topic_depth_3)
# Out:
# 512

# %%
len(unique_topic_depth_1)
# Out:
# 8

# %%
aging_topics_2 = [topic for topic in unique_topic_depth_2 if "Aging" in topic]
aging_topics_2
# Out:
# ['Aging', 'Epigenetic Aging']

# %%
aging_topics_3 = [topic for topic in unique_topic_depth_3 if "Aging" in topic]
aging_topics_3
# Out:
# ['Aging (6)', 'Aging (3)', 'Aging (5)', 'Aging (2)', 'Aging (4)']

# %%
import re

def trim_topic(topic):
    return re.sub(r' \(\d+\)$', '', topic)

merged_df['topic_depth_1'] = merged_df['topic_depth_1'].apply(trim_topic)
merged_df['topic_depth_2'] = merged_df['topic_depth_2'].apply(trim_topic)
merged_df['topic_depth_3'] = merged_df['topic_depth_3'].apply(trim_topic)

# %%
merged_df['topic_depth_1'].unique()
# Out:
# array(['Evolutionary Biology', 'Genomics Analysis', 'Viral Infections',
#        'Microbial Ecology', 'Neural Science', 'Cancer Research',
#        'Cell Biology', 'Neurological Disorders'], dtype=object)

# %%
merged_df.to_csv('../data/biorxiv_nomic.csv', index=False)

# %%
merged_df['topic_depth_2'].unique()
# Out:
# array(['Evolutionary Change', 'Systems Biology', 'Animal Behavior',
#        'Zoonotic Diseases', 'Evolutionary Dynamics',
#        'Genetic Engineering', 'Genetics', 'Neural Networks',
#        'Genetic Traits', 'Genetic Evolution', 'Noncoding RNAs',
#        'Ecosystem Management', 'Genomics', 'Protein Networks',
#        'Glioblastoma', 'Liver Inflammation', 'HIV Research',
#        'Plant Stress', 'Pharmaceuticals', 'Nematode Biology',
#        'Protein Structure', 'Aging', 'Soil Microbiology',
#        "Alzheimer's Disease", 'Parkinsons Disease',
#        'Psychological Disorders', 'Embryonic Development', 'Mitochondria',
#        'Microbial Pathogens', 'Neuroscience', 'Muscle Kinematics',
#        'Biomedical Imaging', 'Learning Theory', 'Memory and Fear',
#        'Virology', 'Single Cell', 'Malaria', 'Influenza Virus',
#        'Gene Expression', 'Microscopy', 'Microbial Ecology',
#        'Immune Response', 'Cell Division', 'Honeybees',
#        'Genome Regulation', 'Neural Development', 'Bacterial Biofilm',
#        'Marine Biology', 'Cell Mechanics', 'Epigenetic Aging',
#        'Cell Biology', 'Brain Processing', 'Hearing',
#        'Drosophila Biology', 'Disease Control', 'Brain Development',
#        'Protein Analysis', 'Pulmonary Disease', 'Agriculture',
#        'Decision Making', 'Diabetes Management', 'Gene Editing',
#        'Neuroimaging', 'Thermoregulation', 'Cancer Treatment',
#        'Ion Channels', 'Inflammatory Bowel', 'Cell Imaging', 'TB Disease',
#        'Zebrafish Biology', 'Medical Imaging', 'Cancer Immunotherapy',
#        'Cardiovascular', 'Microbial Health', 'Health Education',
#        'Muscle Disease', 'Sleep Rhythms', 'Pain Management',
#        'Tissue Engineering', 'Eye Vision', 'Photosynthesis',
#        'Brain Stimulation', 'Antiviral Drugs', 'Exosome Biology',
#        'COVID Vaccine', 'Staphylococcal Infections', 'COVID-19',
#        'Research Paper'], dtype=object)

# %%
len(merged_df['topic_depth_2'].unique())
# Out:
# 88
